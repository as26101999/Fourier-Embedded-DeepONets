# %%
import os
import random
import math
from pathlib import Path

import numpy as np
import scipy.io
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, Subset
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# ============================================================
# 1. Reproducibility
# ============================================================
seed = 42
random.seed(seed)
np.random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)
torch.backends.cudnn.deterministic = True
torch.backends.cudnn.benchmark = False

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)

# ============================================================
# 2. Utility functions
# ============================================================
def set_all_seeds(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

def relative_l2_error_np(gt: np.ndarray, pred: np.ndarray) -> float:
    num = np.linalg.norm(gt - pred)
    den = np.linalg.norm(gt)
    return float(num / (den + 1e-12))

def _resolve_ckpt_path(base_dir: Path, name: str) -> Path:
    ckpt_dir = base_dir / "checkpoints_data_size_study"
    ckpt_dir.mkdir(parents=True, exist_ok=True)
    return ckpt_dir / f"{name}_best.pth"

def _safe_save_same_dir(obj, dest_path: Path):
    tmp_path = dest_path.with_suffix(dest_path.suffix + ".tmp")
    with open(tmp_path, "wb") as f:
        torch.save(obj, f)
    if dest_path.exists():
        try:
            os.remove(dest_path)
        except Exception:
            pass
    os.replace(str(tmp_path), str(dest_path))
    return str(dest_path)

# ============================================================
# 3. Load data
# ============================================================
data_path = "Burger.mat"
data_dir = Path(os.path.abspath(data_path)).parent

mat = scipy.io.loadmat(data_path)
u_all = mat["input"]          # [N, 100]
s_all = mat["output"]         # [N, T, X]
s_all = s_all[:, :100, :]     # keep first 100 time steps

N, T, X = s_all.shape
assert u_all.shape[0] == N and u_all.shape[1] == X == 100, "Unexpected data shape"

print("u_all shape:", u_all.shape)
print("s_all shape:", s_all.shape)

# ============================================================
# 4. Fixed train / val / test split
# ============================================================
X_trainval, X_test, y_trainval, y_test = train_test_split(
    u_all, s_all, test_size=0.20, random_state=seed
)
X_train, X_val, y_train, y_val = train_test_split(
    X_trainval, y_trainval, test_size=0.125, random_state=seed
)
# Final split:
# train = 70%
# val   = 10%
# test  = 20%

print("Train:", X_train.shape, y_train.shape)
print("Val  :", X_val.shape, y_val.shape)
print("Test :", X_test.shape, y_test.shape)

# ============================================================
# 5. Normalize using FULL training set statistics
# ============================================================
mu_ic  = X_train.mean(axis=0, keepdims=True)
std_ic = X_train.std(axis=0, keepdims=True) + 1e-8

mu_sol  = y_train.mean(axis=(0, 1), keepdims=True)
std_sol = y_train.std(axis=(0, 1), keepdims=True) + 1e-8

X_train_n = (X_train - mu_ic) / std_ic
X_val_n   = (X_val   - mu_ic) / std_ic
X_test_n  = (X_test  - mu_ic) / std_ic

y_train_n = (y_train - mu_sol) / std_sol
y_val_n   = (y_val   - mu_sol) / std_sol
y_test_n  = (y_test  - mu_sol) / std_sol

# ============================================================
# 6. Coordinates
# ============================================================
grid = np.linspace(0.0, 1.0, 100)
Xg, Tg = np.meshgrid(grid, grid, indexing='xy')
coords_np = np.stack([Xg, Tg], axis=-1).astype(np.float32)   # [100,100,2]

# ============================================================
# 7. Dataset / dataloader
# ============================================================
class Burgers1DDataset(Dataset):
    def __init__(self, ic, sol, coords):
        self.ic = torch.tensor(ic, dtype=torch.float32)
        self.sol = torch.tensor(sol, dtype=torch.float32)
        self.coords = torch.tensor(coords, dtype=torch.float32)

    def __len__(self):
        return self.ic.shape[0]

    def __getitem__(self, i):
        return self.ic[i], self.sol[i]

train_ds_full = Burgers1DDataset(X_train_n, y_train_n, coords_np)
val_ds        = Burgers1DDataset(X_val_n,   y_val_n,   coords_np)
test_ds       = Burgers1DDataset(X_test_n,  y_test_n,  coords_np)

coords = train_ds_full.coords.to(device)

# ============================================================
# 8. Models
# ============================================================
class FourierEmbedding(nn.Module):
    def __init__(self, input_dim, mapping_size=64, sigma=10.0):
        super().__init__()
        B = torch.randn(input_dim, mapping_size) * sigma
        self.register_buffer("B", B)

    def forward(self, x):
        x_proj = 2 * math.pi * x @ self.B
        return torch.cat([torch.sin(x_proj), torch.cos(x_proj)], dim=-1)

class TrunkFourier(nn.Module):
    def __init__(self, input_dim=2, mapping_size=64, sigma=10.0, hidden=256, out_features=100):
        super().__init__()
        self.embed = FourierEmbedding(input_dim=input_dim, mapping_size=mapping_size, sigma=sigma)
        self.net = nn.Sequential(
            nn.Linear(2 * mapping_size, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, out_features)
        )

    def forward(self, coords):
        x = coords.view(-1, 2)
        x = self.embed(x)
        return self.net(x)

class TrunkMLP(nn.Module):
    def __init__(self, hidden=256, out_features=100):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(2, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, out_features)
        )

    def forward(self, coords):
        x = coords.view(-1, 2)
        return self.net(x)

class Branch(nn.Module):
    def __init__(self, out_features=100):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(100, 50), nn.ReLU(),
            nn.Linear(50, 50), nn.ReLU(),
            nn.Linear(50, 50), nn.ReLU(),
            nn.Linear(50, 50), nn.ReLU(),
            nn.Linear(50, 50), nn.ReLU(),
            nn.Linear(50, out_features)
        )

    def forward(self, ic):
        return self.net(ic)

class DeepONet(nn.Module):
    def __init__(self, trunk, branch_out_features=100):
        super().__init__()
        self.branch = Branch(out_features=branch_out_features)
        self.trunk = trunk

    def forward(self, ic, coords):
        B = ic.size(0)
        G = coords.size(0)  # 100

        trunk_out  = self.trunk(coords)   # [10000,100]
        branch_out = self.branch(ic)      # [B,100]

        y = torch.matmul(branch_out, trunk_out.T)  # [B,10000]
        return y.view(B, G, G)                     # [B,100,100]

# ============================================================
# 9. Denormalization / evaluation
# ============================================================
def denorm_sol(y_norm: torch.Tensor) -> torch.Tensor:
    mu = torch.tensor(mu_sol, dtype=torch.float32, device=y_norm.device)
    sd = torch.tensor(std_sol, dtype=torch.float32, device=y_norm.device)
    return y_norm * sd + mu

@torch.no_grad()
def evaluate_mean_rel_l2(model, loader, device, coords):
    model.eval()
    rels = []

    for ic, gt in loader:
        ic = ic.to(device)
        gt = gt.to(device)

        pred = model(ic, coords)

        pred_d = denorm_sol(pred).cpu().numpy()
        gt_d   = denorm_sol(gt).cpu().numpy()

        for i in range(gt_d.shape[0]):
            rels.append(relative_l2_error_np(gt_d[i], pred_d[i]))

    return float(np.mean(rels))

@torch.no_grad()
def val_rel_l2_global(model, loader, device, coords):
    model.eval()
    num_sq, den_sq = 0.0, 0.0

    for ic, gt in loader:
        ic = ic.to(device)
        gt = gt.to(device)

        pred = model(ic, coords)

        pred_d = denorm_sol(pred)
        gt_d   = denorm_sol(gt)

        e = pred_d - gt_d
        num_sq += torch.sum(e ** 2).item()
        den_sq += torch.sum(gt_d ** 2).item()

    return math.sqrt(num_sq / (den_sq + 1e-20))

# ============================================================
# 10. Train functions
# ============================================================
def train_one_epoch(model, loader, optimizer, criterion, device, coords):
    model.train()
    running_loss = 0.0

    for ic, gt in loader:
        ic = ic.to(device)
        gt = gt.to(device)

        optimizer.zero_grad()
        pred = model(ic, coords)
        loss = criterion(pred, gt)
        loss.backward()
        optimizer.step()

        running_loss += loss.item() * ic.size(0)

    return running_loss / len(loader.dataset)

def fit_model(model, name, train_loader, val_loader, coords, base_dir,
              max_epochs=1000, lr=1e-3, patience=150):
    criterion = nn.MSELoss()
    optimizer = optim.Adam(model.parameters(), lr=lr)
    scheduler = optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode="min", factor=0.5, patience=30
    )

    best_val = float("inf")
    best_path = _resolve_ckpt_path(base_dir, name)
    wait = 0

    hist = {"train_loss": [], "val_rel_l2": []}

    print(f"[INFO] Saving checkpoint to: {best_path}")

    for epoch in range(1, max_epochs + 1):
        tr_loss = train_one_epoch(model, train_loader, optimizer, criterion, device, coords)
        val_r2 = val_rel_l2_global(model, val_loader, device, coords)

        hist["train_loss"].append(tr_loss)
        hist["val_rel_l2"].append(val_r2)
        scheduler.step(val_r2)

        print(f"[{name}] Epoch {epoch:4d}/{max_epochs} | Train MSE(n): {tr_loss:.6e} | Val Rel-L2: {val_r2:.6e}")

        if val_r2 < best_val - 1e-6:
            best_val = val_r2
            _safe_save_same_dir(
                {
                    "epoch": epoch,
                    "model_state": model.state_dict(),
                    "best_val_rel_l2": best_val
                },
                best_path
            )
            wait = 0
        else:
            wait += 1
            if wait >= patience:
                print(f"[{name}] Early stopping at epoch {epoch}. Best Val Rel-L2: {best_val:.6e}")
                break

    return str(best_path), hist

# ============================================================
# 11. Model builders
# ============================================================
def build_deeponet():
    return DeepONet(
        trunk=TrunkMLP(hidden=256, out_features=100),
        branch_out_features=100
    ).to(device)

def build_fedonet(mapping_size=64, sigma=10.0):
    return DeepONet(
        trunk=TrunkFourier(
            input_dim=2,
            mapping_size=mapping_size,
            sigma=sigma,
            hidden=256,
            out_features=100
        ),
        branch_out_features=100
    ).to(device)

# ============================================================
# 12. Data-size sweep
# ============================================================
def make_subset_loader(dataset, n_samples, batch_size=128, shuffle=True):
    indices = np.arange(len(dataset))[:n_samples]
    subset = Subset(dataset, indices.tolist())
    loader = DataLoader(subset, batch_size=batch_size, shuffle=shuffle, drop_last=False)
    return loader, subset

def run_data_size_study(
    train_dataset,
    val_dataset,
    test_dataset,
    coords,
    train_sizes,
    fed_mapping_size=64,
    fed_sigma=10.0,
    batch_size=128,
    max_epochs=1000,
    lr=1e-3,
    patience=150,
):
    val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False, drop_last=False)
    test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, drop_last=False)

    results = {
        "train_size": [],
        "deeponet_val_rel_l2": [],
        "deeponet_test_rel_l2": [],
        "fedonet_val_rel_l2": [],
        "fedonet_test_rel_l2": [],
    }

    for n_train in train_sizes:
        print("\n" + "=" * 100)
        print(f"Training with n_train = {n_train}")
        print("=" * 100)

        train_loader, _ = make_subset_loader(
            train_dataset, n_samples=n_train, batch_size=batch_size, shuffle=True
        )

        # ---------------- DeepONet ----------------
        set_all_seeds(seed)
        deeponet = build_deeponet()

        deep_ckpt, _ = fit_model(
            model=deeponet,
            name=f"deeponet_n{n_train}",
            train_loader=train_loader,
            val_loader=val_loader,
            coords=coords,
            base_dir=data_dir,
            max_epochs=max_epochs,
            lr=lr,
            patience=patience
        )

        deep_ckpt_data = torch.load(deep_ckpt, map_location=device)
        deeponet.load_state_dict(deep_ckpt_data["model_state"])

        deep_best_val = float(deep_ckpt_data["best_val_rel_l2"])
        deep_test_rel = evaluate_mean_rel_l2(deeponet, test_loader, device, coords)

        print(f"[DeepONet | n={n_train}] Best Val Rel-L2 : {deep_best_val:.6e}")
        print(f"[DeepONet | n={n_train}] Test Mean Rel-L2: {deep_test_rel:.6e}")

        # ---------------- FEDONet ----------------
        set_all_seeds(seed)
        fedonet = build_fedonet(mapping_size=fed_mapping_size, sigma=fed_sigma)

        fed_ckpt, _ = fit_model(
            model=fedonet,
            name=f"fedonet_n{n_train}",
            train_loader=train_loader,
            val_loader=val_loader,
            coords=coords,
            base_dir=data_dir,
            max_epochs=max_epochs,
            lr=lr,
            patience=patience
        )

        fed_ckpt_data = torch.load(fed_ckpt, map_location=device)
        fedonet.load_state_dict(fed_ckpt_data["model_state"])

        fed_best_val = float(fed_ckpt_data["best_val_rel_l2"])
        fed_test_rel = evaluate_mean_rel_l2(fedonet, test_loader, device, coords)

        print(f"[FEDONet  | n={n_train}] Best Val Rel-L2 : {fed_best_val:.6e}")
        print(f"[FEDONet  | n={n_train}] Test Mean Rel-L2: {fed_test_rel:.6e}")

        results["train_size"].append(n_train)
        results["deeponet_val_rel_l2"].append(deep_best_val)
        results["deeponet_test_rel_l2"].append(deep_test_rel)
        results["fedonet_val_rel_l2"].append(fed_best_val)
        results["fedonet_test_rel_l2"].append(fed_test_rel)

        del deeponet, fedonet
        if torch.cuda.is_available():
            torch.cuda.empty_cache()

    return results

# ============================================================
# 13. Choose training sizes
# ============================================================
n_train_full = len(train_ds_full)
print("Full training set size:", n_train_full)

# Use absolute training sizes
train_sizes = [50, 100, 300, 400, 500, 800, 900]
train_sizes = [n for n in train_sizes if n <= n_train_full]

# If your dataset is smaller than some requested sizes, they are removed.
print("Training sizes used:", train_sizes)

# ============================================================
# 14. Run the study
# ============================================================
results = run_data_size_study(
    train_dataset=train_ds_full,
    val_dataset=val_ds,
    test_dataset=test_ds,
    coords=coords,
    train_sizes=train_sizes,
    fed_mapping_size=512,   # adjust if you want
    fed_sigma=10.0,
    batch_size=128,
    max_epochs=1000,       # reduce if runtime is too high
    lr=1e-3,
    patience=15000
)

# ============================================================
# 15. Summary table in terminal
# ============================================================
train_sizes_arr = np.array(results["train_size"])
deep_val_arr    = np.array(results["deeponet_val_rel_l2"])
deep_test_arr   = np.array(results["deeponet_test_rel_l2"])
fed_val_arr     = np.array(results["fedonet_val_rel_l2"])
fed_test_arr    = np.array(results["fedonet_test_rel_l2"])

print("\n" + "=" * 110)
print("FINAL SUMMARY: Training Data Size vs Rel-L2 Error")
print("=" * 110)
for n, dv, dt, fv, ft in zip(train_sizes_arr, deep_val_arr, deep_test_arr, fed_val_arr, fed_test_arr):
    print(
        f"n_train={n:4d} | "
        f"DeepONet  Val={dv:.6e}, Test={dt:.6e} | "
        f"FEDONet  Val={fv:.6e}, Test={ft:.6e}"
    )

# ============================================================
# 16. Plot test Rel-L2 vs training size
# ============================================================
plt.figure(figsize=(8, 5))
plt.plot(train_sizes_arr, deep_test_arr, marker='o', linewidth=2, label='DeepONet Test Rel-L2')
plt.plot(train_sizes_arr, fed_test_arr, marker='s', linewidth=2, label='FEDONet Test Rel-L2')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Training Samples', fontsize=13)
plt.ylabel('Mean Test Relative L2 Error', fontsize=13)
plt.title('Effect of Training Data Size on Test Rel-L2 Error', fontsize=14)
plt.grid(True, which='both', linestyle='--', alpha=0.4)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()

# ============================================================
# 17. Plot validation Rel-L2 vs training size
# ============================================================
plt.figure(figsize=(8, 5))
plt.plot(train_sizes_arr, deep_val_arr, marker='o', linewidth=2, label='DeepONet Best Val Rel-L2')
plt.plot(train_sizes_arr, fed_val_arr, marker='s', linewidth=2, label='FEDONet Best Val Rel-L2')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Number of Training Samples', fontsize=13)
plt.ylabel('Best Validation Relative L2 Error', fontsize=13)
plt.title('Effect of Training Data Size on Validation Rel-L2 Error', fontsize=14)
plt.grid(True, which='both', linestyle='--', alpha=0.4)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()

# ============================================================
# 18. Optional combined plot with percentage of full training set
# ============================================================
train_percent = 100.0 * train_sizes_arr / n_train_full

plt.figure(figsize=(8, 5))
plt.plot(train_percent, deep_test_arr, marker='o', linewidth=2, label='DeepONet Test Rel-L2')
plt.plot(train_percent, fed_test_arr, marker='s', linewidth=2, label='FEDONet Test Rel-L2')
plt.yscale('log')
plt.xlabel('Training Set Size (% of Full Training Set)', fontsize=13)
plt.ylabel('Mean Test Relative L2 Error', fontsize=13)
plt.title('Test Rel-L2 vs Fraction of Training Data', fontsize=14)
plt.grid(True, which='both', linestyle='--', alpha=0.4)
plt.legend(fontsize=11)
plt.tight_layout()
plt.show()
# Out:
# Using device: cuda
# u_all shape: (1250, 100)
# s_all shape: (1250, 100, 100)
# Train: (875, 100) (875, 100, 100)
# Val  : (125, 100) (125, 100, 100)
# Test : (250, 100) (250, 100, 100)
# Full training set size: 875
# Training sizes used: [50, 100, 300, 400, 500, 800]
#
# ====================================================================================================
# Training with n_train = 50
# ====================================================================================================
# [INFO] Saving checkpoint to: c:\Users\asojitra\Documents\DeepONets_Serious\Data_generation\Burgers_GRF_initialisation\checkpoints_data_size_study\deeponet_n50_best.pth
# [deeponet_n50] Epoch    1/1000 | Train MSE(n): 8.759016e-01 | Val Rel-L2: 1.001060e+00
# [deeponet_n50] Epoch    2/1000 | Train MSE(n): 8.610864e-01 | Val Rel-L2: 1.003016e+00
# [deeponet_n50] Epoch    3/1000 | Train MSE(n): 8.649253e-01 | Val Rel-L2: 1.002387e+00
# [deeponet_n50] Epoch    4/1000 | Train MSE(n): 8.636367e-01 | Val Rel-L2: 1.001265e+00
# [deeponet_n50] Epoch    5/1000 | Train MSE(n): 8.613311e-01 | Val Rel-L2: 1.000936e+00
# [deeponet_n50] Epoch    6/1000 | Train MSE(n): 8.607681e-01 | Val Rel-L2: 1.001038e+00
# [deeponet_n50] Epoch    7/1000 | Train MSE(n): 8.610204e-01 | Val Rel-L2: 1.001143e+00
# [deeponet_n50] Epoch    8/1000 | Train MSE(n): 8.611801e-01 | Val Rel-L2: 1.001058e+00
# [deeponet_n50] Epoch    9/1000 | Train MSE(n): 8.608376e-01 | Val Rel-L2: 1.000789e+00
# [deeponet_n50] Epoch   10/1000 | Train MSE(n): 8.600534e-01 | Val Rel-L2: 1.000448e+00
# [deeponet_n50] Epoch   11/1000 | Train MSE(n): 8.589960e-01 | Val Rel-L2: 1.000060e+00
# [deeponet_n50] Epoch   12/1000 | Train MSE(n): 8.576701e-01 | Val Rel-L2: 9.994752e-01
# [deeponet_n50] Epoch   13/1000 | Train MSE(n): 8.557183e-01 | Val Rel-L2: 9.983847e-01
# [deeponet_n50] Epoch   14/1000 | Train MSE(n): 8.523096e-01 | Val Rel-L2: 9.965299e-01
# [deeponet_n50] Epoch   15/1000 | Train MSE(n): 8.467171e-01 | Val Rel-L2: 9.936948e-01
# [deeponet_n50] Epoch   16/1000 | Train MSE(n): 8.383376e-01 | Val Rel-L2: 9.889171e-01
# [deeponet_n50] Epoch   17/1000 | Train MSE(n): 8.247231e-01 | Val Rel-L2: 9.811457e-01
# [deeponet_n50] Epoch   18/1000 | Train MSE(n): 8.034348e-01 | Val Rel-L2: 9.690095e-01
# [deeponet_n50] Epoch   19/1000 | Train MSE(n): 7.713357e-01 | Val Rel-L2: 9.505300e-01
# [deeponet_n50] Epoch   20/1000 | Train MSE(n): 7.244267e-01 | Val Rel-L2: 9.254099e-01
# [deeponet_n50] Epoch   21/1000 | Train MSE(n): 6.637382e-01 | Val Rel-L2: 8.981711e-01
# [deeponet_n50] Epoch   22/1000 | Train MSE(n): 6.015476e-01 | Val Rel-L2: 8.805253e-01
# [deeponet_n50] Epoch   23/1000 | Train MSE(n): 5.675181e-01 | Val Rel-L2: 8.686808e-01
# [deeponet_n50] Epoch   24/1000 | Train MSE(n): 5.491665e-01 | Val Rel-L2: 8.622547e-01
# [deeponet_n50] Epoch   25/1000 | Train MSE(n): 5.252056e-01 | Val Rel-L2: 8.538393e-01
# [deeponet_n50] Epoch   26/1000 | Train MSE(n): 5.040946e-01 | Val Rel-L2: 8.569294e-01
# [deeponet_n50] Epoch   27/1000 | Train MSE(n): 4.966121e-01 | Val Rel-L2: 8.630468e-01
# [deeponet_n50] Epoch   28/1000 | Train MSE(n): 4.959857e-01 | Val Rel-L2: 8.631899e-01
# [deeponet_n50] Epoch   29/1000 | Train MSE(n): 4.944437e-01 | Val Rel-L2: 8.595461e-01
# [deeponet_n50] Epoch   30/1000 | Train MSE(n): 4.922642e-01 | Val Rel-L2: 8.565219e-01
# [deeponet_n50] Epoch   31/1000 | Train MSE(n): 4.911318e-01 | Val Rel-L2: 8.540984e-01
# [deeponet_n50] Epoch   32/1000 | Train MSE(n): 4.883589e-01 | Val Rel-L2: 8.495920e-01
# [deeponet_n50] Epoch   33/1000 | Train MSE(n): 4.831648e-01 | Val Rel-L2: 8.425853e-01
# [deeponet_n50] Epoch   34/1000 | Train MSE(n): 4.749389e-01 | Val Rel-L2: 8.367350e-01
# [deeponet_n50] Epoch   35/1000 | Train MSE(n): 4.658454e-01 | Val Rel-L2: 8.336318e-01
# [deeponet_n50] Epoch   36/1000 | Train MSE(n): 4.562889e-01 | Val Rel-L2: 8.328346e-01
# [deeponet_n50] Epoch   37/1000 | Train MSE(n): 4.501810e-01 | Val Rel-L2: 8.321438e-01
# [deeponet_n50] Epoch   38/1000 | Train MSE(n): 4.479542e-01 | Val Rel-L2: 8.316160e-01
# [deeponet_n50] Epoch   39/1000 | Train MSE(n): 4.465290e-01 | Val Rel-L2: 8.301136e-01
# [deeponet_n50] Epoch   40/1000 | Train MSE(n): 4.418577e-01 | Val Rel-L2: 8.257600e-01
# [deeponet_n50] Epoch   41/1000 | Train MSE(n): 4.365606e-01 | Val Rel-L2: 8.209672e-01
# [deeponet_n50] Epoch   42/1000 | Train MSE(n): 4.315850e-01 | Val Rel-L2: 8.185833e-01
# [deeponet_n50] Epoch   43/1000 | Train MSE(n): 4.250809e-01 | Val Rel-L2: 8.170681e-01
# [deeponet_n50] Epoch   44/1000 | Train MSE(n): 4.189124e-01 | Val Rel-L2: 8.129665e-01
# [deeponet_n50] Epoch   45/1000 | Train MSE(n): 4.132589e-01 | Val Rel-L2: 8.088676e-01
# [deeponet_n50] Epoch   46/1000 | Train MSE(n): 4.052065e-01 | Val Rel-L2: 8.044708e-01
# [deeponet_n50] Epoch   47/1000 | Train MSE(n): 3.969730e-01 | Val Rel-L2: 7.979398e-01
# [deeponet_n50] Epoch   48/1000 | Train MSE(n): 3.884660e-01 | Val Rel-L2: 7.960754e-01
# [deeponet_n50] Epoch   49/1000 | Train MSE(n): 3.791949e-01 | Val Rel-L2: 7.893533e-01
# [deeponet_n50] Epoch   50/1000 | Train MSE(n): 3.717121e-01 | Val Rel-L2: 7.888062e-01
# [deeponet_n50] Epoch   51/1000 | Train MSE(n): 3.650935e-01 | Val Rel-L2: 7.765023e-01
# [deeponet_n50] Epoch   52/1000 | Train MSE(n): 3.627976e-01 | Val Rel-L2: 7.870624e-01
# [deeponet_n50] Epoch   53/1000 | Train MSE(n): 3.658293e-01 | Val Rel-L2: 7.685610e-01
# [deeponet_n50] Epoch   54/1000 | Train MSE(n): 3.492669e-01 | Val Rel-L2: 7.635172e-01
# [deeponet_n50] Epoch   55/1000 | Train MSE(n): 3.373310e-01 | Val Rel-L2: 7.736165e-01
# [deeponet_n50] Epoch   56/1000 | Train MSE(n): 3.477266e-01 | Val Rel-L2: 7.599532e-01
# [deeponet_n50] Epoch   57/1000 | Train MSE(n): 3.311823e-01 | Val Rel-L2: 7.628622e-01
# [deeponet_n50] Epoch   58/1000 | Train MSE(n): 3.312378e-01 | Val Rel-L2: 7.618339e-01
# [deeponet_n50] Epoch   59/1000 | Train MSE(n): 3.287955e-01 | Val Rel-L2: 7.535198e-01
# [deeponet_n50] Epoch   60/1000 | Train MSE(n): 3.218100e-01 | Val Rel-L2: 7.601234e-01
# [deeponet_n50] Epoch   61/1000 | Train MSE(n): 3.209894e-01 | Val Rel-L2: 7.540398e-01
# [deeponet_n50] Epoch   62/1000 | Train MSE(n): 3.115187e-01 | Val Rel-L2: 7.424871e-01
# [deeponet_n50] Epoch   63/1000 | Train MSE(n): 3.133172e-01 | Val Rel-L2: 7.395019e-01
# [deeponet_n50] Epoch   64/1000 | Train MSE(n): 3.004770e-01 | Val Rel-L2: 7.498960e-01
# [deeponet_n50] Epoch   65/1000 | Train MSE(n): 3.031196e-01 | Val Rel-L2: 7.275430e-01
# [deeponet_n50] Epoch   66/1000 | Train MSE(n): 2.873699e-01 | Val Rel-L2: 7.129917e-01
# [deeponet_n50] Epoch   67/1000 | Train MSE(n): 2.858222e-01 | Val Rel-L2: 7.083854e-01
# [deeponet_n50] Epoch   68/1000 | Train MSE(n): 2.682236e-01 | Val Rel-L2: 7.001246e-01
# [deeponet_n50] Epoch   69/1000 | Train MSE(n): 2.592182e-01 | Val Rel-L2: 6.607440e-01
# [deeponet_n50] Epoch   70/1000 | Train MSE(n): 2.374563e-01 | Val Rel-L2: 6.304877e-01
# [deeponet_n50] Epoch   71/1000 | Train MSE(n): 2.220133e-01 | Val Rel-L2: 6.138775e-01
# [deeponet_n50] Epoch   72/1000 | Train MSE(n): 2.014099e-01 | Val Rel-L2: 5.860398e-01
# [deeponet_n50] Epoch   73/1000 | Train MSE(n): 1.861250e-01 | Val Rel-L2: 5.598727e-01
# [deeponet_n50] Epoch   74/1000 | Train MSE(n): 1.816256e-01 | Val Rel-L2: 5.517902e-01
# [deeponet_n50] Epoch   75/1000 | Train MSE(n): 1.718312e-01 | Val Rel-L2: 5.483566e-01
# [deeponet_n50] Epoch   76/1000 | Train MSE(n): 1.690164e-01 | Val Rel-L2: 5.294001e-01
# [deeponet_n50] Epoch   77/1000 | Train MSE(n): 1.609000e-01 | Val Rel-L2: 5.196186e-01
# [deeponet_n50] Epoch   78/1000 | Train MSE(n): 1.462375e-01 | Val Rel-L2: 5.157755e-01
# [deeponet_n50] Epoch   79/1000 | Train MSE(n): 1.367078e-01 | Val Rel-L2: 5.052005e-01
# [deeponet_n50] Epoch   80/1000 | Train MSE(n): 1.289883e-01 | Val Rel-L2: 4.965198e-01
# [deeponet_n50] Epoch   81/1000 | Train MSE(n): 1.204721e-01 | Val Rel-L2: 4.899921e-01
# [deeponet_n50] Epoch   82/1000 | Train MSE(n): 1.162570e-01 | Val Rel-L2: 4.719805e-01
# [deeponet_n50] Epoch   83/1000 | Train MSE(n): 1.123225e-01 | Val Rel-L2: 4.662023e-01
# [deeponet_n50] Epoch   84/1000 | Train MSE(n): 1.070464e-01 | Val Rel-L2: 4.464135e-01
# [deeponet_n50] Epoch   85/1000 | Train MSE(n): 1.019831e-01 | Val Rel-L2: 4.263194e-01
# [deeponet_n50] Epoch   86/1000 | Train MSE(n): 9.955339e-02 | Val Rel-L2: 4.193797e-01
# [deeponet_n50] Epoch   87/1000 | Train MSE(n): 9.444612e-02 | Val Rel-L2: 4.015178e-01
# [deeponet_n50] Epoch   88/1000 | Train MSE(n): 8.865620e-02 | Val Rel-L2: 3.905697e-01
# [deeponet_n50] Epoch   89/1000 | Train MSE(n): 8.483275e-02 | Val Rel-L2: 3.884164e-01
# [deeponet_n50] Epoch   90/1000 | Train MSE(n): 8.248975e-02 | Val Rel-L2: 3.801971e-01
# [deeponet_n50] Epoch   91/1000 | Train MSE(n): 8.059672e-02 | Val Rel-L2: 3.752582e-01
# [deeponet_n50] Epoch   92/1000 | Train MSE(n): 7.805288e-02 | Val Rel-L2: 3.704211e-01
# [deeponet_n50] Epoch   93/1000 | Train MSE(n): 7.506974e-02 | Val Rel-L2: 3.644239e-01
# [deeponet_n50] Epoch   94/1000 | Train MSE(n): 7.244328e-02 | Val Rel-L2: 3.634970e-01
# [deeponet_n50] Epoch   95/1000 | Train MSE(n): 7.048836e-02 | Val Rel-L2: 3.571024e-01
# [deeponet_n50] Epoch   96/1000 | Train MSE(n): 6.879690e-02 | Val Rel-L2: 3.576452e-01
# [deeponet_n50] Epoch   97/1000 | Train MSE(n): 6.741075e-02 | Val Rel-L2: 3.595734e-01
# [deeponet_n50] Epoch   98/1000 | Train MSE(n): 6.703588e-02 | Val Rel-L2: 3.594532e-01
# [deeponet_n50] Epoch   99/1000 | Train MSE(n): 6.642372e-02 | Val Rel-L2: 3.631250e-01
# [deeponet_n50] Epoch  100/1000 | Train MSE(n): 6.687772e-02 | Val Rel-L2: 3.673610e-01
# [deeponet_n50] Epoch  101/1000 | Train MSE(n): 6.991839e-02 | Val Rel-L2: 3.784229e-01
# [deeponet_n50] Epoch  102/1000 | Train MSE(n): 8.004592e-02 | Val Rel-L2: 3.944089e-01
# [deeponet_n50] Epoch  103/1000 | Train MSE(n): 9.066318e-02 | Val Rel-L2: 3.729613e-01
# [deeponet_n50] Epoch  104/1000 | Train MSE(n): 8.289770e-02 | Val Rel-L2: 3.495752e-01
# [deeponet_n50] Epoch  105/1000 | Train MSE(n): 6.292078e-02 | Val Rel-L2: 3.804617e-01
# [deeponet_n50] Epoch  106/1000 | Train MSE(n): 8.249363e-02 | Val Rel-L2: 3.625354e-01
# [deeponet_n50] Epoch  107/1000 | Train MSE(n): 7.577419e-02 | Val Rel-L2: 3.514045e-01
# [deeponet_n50] Epoch  108/1000 | Train MSE(n): 6.756005e-02 | Val Rel-L2: 3.711779e-01
# [deeponet_n50] Epoch  109/1000 | Train MSE(n): 7.527198e-02 | Val Rel-L2: 3.501847e-01
# [deeponet_n50] Epoch  110/1000 | Train MSE(n): 6.200052e-02 | Val Rel-L2: 3.591757e-01
# [deeponet_n50] Epoch  111/1000 | Train MSE(n): 7.047497e-02 | Val Rel-L2: 3.452714e-01
# [deeponet_n50] Epoch  112/1000 | Train MSE(n): 6.048112e-02 | Val Rel-L2: 3.614621e-01
# [deeponet_n50] Epoch  113/1000 | Train MSE(n): 6.913527e-02 | Val Rel-L2: 3.405067e-01
# [deeponet_n50] Epoch  114/1000 | Train MSE(n): 5.905847e-02 | Val Rel-L2: 3.466101e-01
# [deeponet_n50] Epoch  115/1000 | Train MSE(n): 6.505780e-02 | Val Rel-L2: 3.406383e-01
# [deeponet_n50] Epoch  116/1000 | Train MSE(n): 5.833158e-02 | Val Rel-L2: 3.509500e-01
# [deeponet_n50] Epoch  117/1000 | Train MSE(n): 6.259823e-02 | Val Rel-L2: 3.354257e-01
# [deeponet_n50] Epoch  118/1000 | Train MSE(n): 5.753303e-02 | Val Rel-L2: 3.383372e-01
# [deeponet_n50] Epoch  119/1000 | Train MSE(n): 6.017882e-02 | Val Rel-L2: 3.363413e-01
# [deeponet_n50] Epoch  120/1000 | Train MSE(n): 5.594881e-02 | Val Rel-L2: 3.429956e-01
# [deeponet_n50] Epoch  121/1000 | Train MSE(n): 5.838836e-02 | Val Rel-L2: 3.324935e-01
# [deeponet_n50] Epoch  122/1000 | Train MSE(n): 5.488763e-02 | Val Rel-L2: 3.328767e-01
# [deeponet_n50] Epoch  123/1000 | Train MSE(n): 5.647765e-02 | Val Rel-L2: 3.315862e-01
# [deeponet_n50] Epoch  124/1000 | Train MSE(n): 5.341347e-02 | Val Rel-L2: 3.351679e-01
# [deeponet_n50] Epoch  125/1000 | Train MSE(n): 5.475626e-02 | Val Rel-L2: 3.251887e-01
# [deeponet_n50] Epoch  126/1000 | Train MSE(n): 5.200140e-02 | Val Rel-L2: 3.248488e-01
# [deeponet_n50] Epoch  127/1000 | Train MSE(n): 5.321628e-02 | Val Rel-L2: 3.238968e-01
# [deeponet_n50] Epoch  128/1000 | Train MSE(n): 5.065462e-02 | Val Rel-L2: 3.266265e-01
# [deeponet_n50] Epoch  129/1000 | Train MSE(n): 5.137905e-02 | Val Rel-L2: 3.195932e-01
# [deeponet_n50] Epoch  130/1000 | Train MSE(n): 4.940154e-02 | Val Rel-L2: 3.187436e-01
# [deeponet_n50] Epoch  131/1000 | Train MSE(n): 4.963386e-02 | Val Rel-L2: 3.188070e-01
# [deeponet_n50] Epoch  132/1000 | Train MSE(n): 4.807153e-02 | Val Rel-L2: 3.181103e-01
# [deeponet_n50] Epoch  133/1000 | Train MSE(n): 4.793645e-02 | Val Rel-L2: 3.129922e-01
# [deeponet_n50] Epoch  134/1000 | Train MSE(n): 4.696306e-02 | Val Rel-L2: 3.104631e-01
# [deeponet_n50] Epoch  135/1000 | Train MSE(n): 4.635973e-02 | Val Rel-L2: 3.098699e-01
# [deeponet_n50] Epoch  136/1000 | Train MSE(n): 4.576543e-02 | Val Rel-L2: 3.069850e-01
# [deeponet_n50] Epoch  137/1000 | Train MSE(n): 4.490528e-02 | Val Rel-L2: 3.046025e-01
# [deeponet_n50] Epoch  138/1000 | Train MSE(n): 4.470873e-02 | Val Rel-L2: 3.015435e-01
# [deeponet_n50] Epoch  139/1000 | Train MSE(n): 4.349795e-02 | Val Rel-L2: 3.010606e-01
# [deeponet_n50] Epoch  140/1000 | Train MSE(n): 4.346909e-02 | Val Rel-L2: 2.973569e-01
# [deeponet_n50] Epoch  141/1000 | Train MSE(n): 4.234502e-02 | Val Rel-L2: 2.956088e-01
# [deeponet_n50] Epoch  142/1000 | Train MSE(n): 4.221684e-02 | Val Rel-L2: 2.936012e-01
# [deeponet_n50] Epoch  143/1000 | Train MSE(n): 4.134778e-02 | Val Rel-L2: 2.914527e-01
# [deeponet_n50] Epoch  144/1000 | Train MSE(n): 4.087644e-02 | Val Rel-L2: 2.884871e-01
# [deeponet_n50] Epoch  145/1000 | Train MSE(n): 4.042090e-02 | Val Rel-L2: 2.859798e-01
# [deeponet_n50] Epoch  146/1000 | Train MSE(n): 3.964668e-02 | Val Rel-L2: 2.846597e-01
# [deeponet_n50] Epoch  147/1000 | Train MSE(n): 3.940546e-02 | Val Rel-L2: 2.821014e-01
# [deeponet_n50] Epoch  148/1000 | Train MSE(n): 3.869713e-02 | Val Rel-L2: 2.806652e-01
# [deeponet_n50] Epoch  149/1000 | Train MSE(n): 3.827691e-02 | Val Rel-L2: 2.801658e-01
# [deeponet_n50] Epoch  150/1000 | Train MSE(n): 3.793495e-02 | Val Rel-L2: 2.774116e-01
# [deeponet_n50] Epoch  151/1000 | Train MSE(n): 3.729569e-02 | Val Rel-L2: 2.762413e-01
# [deeponet_n50] Epoch  152/1000 | Train MSE(n): 3.711912e-02 | Val Rel-L2: 2.749768e-01
# [deeponet_n50] Epoch  153/1000 | Train MSE(n): 3.664088e-02 | Val Rel-L2: 2.742005e-01
# [deeponet_n50] Epoch  154/1000 | Train MSE(n): 3.643497e-02 | Val Rel-L2: 2.725915e-01
# [deeponet_n50] Epoch  155/1000 | Train MSE(n): 3.649222e-02 | Val Rel-L2: 2.735145e-01
# [deeponet_n50] Epoch  156/1000 | Train MSE(n): 3.671180e-02 | Val Rel-L2: 2.743581e-01
# [deeponet_n50] Epoch  157/1000 | Train MSE(n): 3.760229e-02 | Val Rel-L2: 2.765766e-01
# [deeponet_n50] Epoch  158/1000 | Train MSE(n): 3.854870e-02 | Val Rel-L2: 2.748322e-01
# [deeponet_n50] Epoch  159/1000 | Train MSE(n): 3.825459e-02 | Val Rel-L2: 2.717376e-01
# [deeponet_n50] Epoch  160/1000 | Train MSE(n): 3.637753e-02 | Val Rel-L2: 2.659617e-01
# [deeponet_n50] Epoch  161/1000 | Train MSE(n): 3.375057e-02 | Val Rel-L2: 2.627586e-01
# [deeponet_n50] Epoch  162/1000 | Train MSE(n): 3.231202e-02 | Val Rel-L2: 2.642796e-01
# [deeponet_n50] Epoch  163/1000 | Train MSE(n): 3.293375e-02 | Val Rel-L2: 2.657406e-01
# [deeponet_n50] Epoch  164/1000 | Train MSE(n): 3.393620e-02 | Val Rel-L2: 2.661193e-01
# [deeponet_n50] Epoch  165/1000 | Train MSE(n): 3.382951e-02 | Val Rel-L2: 2.622244e-01
# [deeponet_n50] Epoch  166/1000 | Train MSE(n): 3.228898e-02 | Val Rel-L2: 2.594103e-01
# [deeponet_n50] Epoch  167/1000 | Train MSE(n): 3.061598e-02 | Val Rel-L2: 2.588700e-01
# [deeponet_n50] Epoch  168/1000 | Train MSE(n): 3.035601e-02 | Val Rel-L2: 2.591608e-01
# [deeponet_n50] Epoch  169/1000 | Train MSE(n): 3.096167e-02 | Val Rel-L2: 2.591506e-01
# [deeponet_n50] Epoch  170/1000 | Train MSE(n): 3.127418e-02 | Val Rel-L2: 2.571647e-01
# [deeponet_n50] Epoch  171/1000 | Train MSE(n): 3.059826e-02 | Val Rel-L2: 2.545723e-01
# [deeponet_n50] Epoch  172/1000 | Train MSE(n): 2.939521e-02 | Val Rel-L2: 2.529330e-01
# [deeponet_n50] Epoch  173/1000 | Train MSE(n): 2.871654e-02 | Val Rel-L2: 2.528694e-01
# [deeponet_n50] Epoch  174/1000 | Train MSE(n): 2.885112e-02 | Val Rel-L2: 2.532832e-01
# [deeponet_n50] Epoch  175/1000 | Train MSE(n): 2.924178e-02 | Val Rel-L2: 2.533118e-01
# [deeponet_n50] Epoch  176/1000 | Train MSE(n): 2.919075e-02 | Val Rel-L2: 2.518205e-01
# [deeponet_n50] Epoch  177/1000 | Train MSE(n): 2.861321e-02 | Val Rel-L2: 2.509181e-01
# [deeponet_n50] Epoch  178/1000 | Train MSE(n): 2.792497e-02 | Val Rel-L2: 2.498518e-01
# [deeponet_n50] Epoch  179/1000 | Train MSE(n): 2.747952e-02 | Val Rel-L2: 2.493048e-01
# [deeponet_n50] Epoch  180/1000 | Train MSE(n): 2.744028e-02 | Val Rel-L2: 2.498295e-01
# [deeponet_n50] Epoch  181/1000 | Train MSE(n): 2.761270e-02 | Val Rel-L2: 2.500860e-01
# [deeponet_n50] Epoch  182/1000 | Train MSE(n): 2.779046e-02 | Val Rel-L2: 2.502552e-01
# [deeponet_n50] Epoch  183/1000 | Train MSE(n): 2.781009e-02 | Val Rel-L2: 2.491727e-01
# [deeponet_n50] Epoch  184/1000 | Train MSE(n): 2.764768e-02 | Val Rel-L2: 2.489330e-01
# [deeponet_n50] Epoch  185/1000 | Train MSE(n): 2.728928e-02 | Val Rel-L2: 2.476739e-01
# [deeponet_n50] Epoch  186/1000 | Train MSE(n): 2.683834e-02 | Val Rel-L2: 2.468917e-01
# [deeponet_n50] Epoch  187/1000 | Train MSE(n): 2.644400e-02 | Val Rel-L2: 2.462193e-01
# [deeponet_n50] Epoch  188/1000 | Train MSE(n): 2.616274e-02 | Val Rel-L2: 2.458582e-01
# [deeponet_n50] Epoch  189/1000 | Train MSE(n): 2.603310e-02 | Val Rel-L2: 2.457882e-01
# [deeponet_n50] Epoch  190/1000 | Train MSE(n): 2.599919e-02 | Val Rel-L2: 2.455217e-01
# [deeponet_n50] Epoch  191/1000 | Train MSE(n): 2.601543e-02 | Val Rel-L2: 2.460331e-01
# [deeponet_n50] Epoch  192/1000 | Train MSE(n): 2.609058e-02 | Val Rel-L2: 2.456285e-01
# [deeponet_n50] Epoch  193/1000 | Train MSE(n): 2.623277e-02 | Val Rel-L2: 2.466823e-01
# [deeponet_n50] Epoch  194/1000 | Train MSE(n): 2.647116e-02 | Val Rel-L2: 2.467925e-01
# [deeponet_n50] Epoch  195/1000 | Train MSE(n): 2.682572e-02 | Val Rel-L2: 2.482596e-01
# [deeponet_n50] Epoch  196/1000 | Train MSE(n): 2.727206e-02 | Val Rel-L2: 2.483764e-01
# [deeponet_n50] Epoch  197/1000 | Train MSE(n): 2.775124e-02 | Val Rel-L2: 2.501963e-01
# [deeponet_n50] Epoch  198/1000 | Train MSE(n): 2.797582e-02 | Val Rel-L2: 2.489292e-01
# [deeponet_n50] Epoch  199/1000 | Train MSE(n): 2.786407e-02 | Val Rel-L2: 2.482118e-01
# [deeponet_n50] Epoch  200/1000 | Train MSE(n): 2.720298e-02 | Val Rel-L2: 2.454584e-01
# [deeponet_n50] Epoch  201/1000 | Train MSE(n): 2.604822e-02 | Val Rel-L2: 2.438835e-01
# [deeponet_n50] Epoch  202/1000 | Train MSE(n): 2.494716e-02 | Val Rel-L2: 2.426068e-01
# [deeponet_n50] Epoch  203/1000 | Train MSE(n): 2.445743e-02 | Val Rel-L2: 2.431748e-01
# [deeponet_n50] Epoch  204/1000 | Train MSE(n): 2.464566e-02 | Val Rel-L2: 2.450137e-01
# [deeponet_n50] Epoch  205/1000 | Train MSE(n): 2.520070e-02 | Val Rel-L2: 2.457402e-01
# [deeponet_n50] Epoch  206/1000 | Train MSE(n): 2.563908e-02 | Val Rel-L2: 2.464367e-01
# [deeponet_n50] Epoch  207/1000 | Train MSE(n): 2.565302e-02 | Val Rel-L2: 2.453495e-01
# [deeponet_n50] Epoch  208/1000 | Train MSE(n): 2.523236e-02 | Val Rel-L2: 2.441567e-01
# [deeponet_n50] Epoch  209/1000 | Train MSE(n): 2.455762e-02 | Val Rel-L2: 2.428264e-01
# [deeponet_n50] Epoch  210/1000 | Train MSE(n): 2.397591e-02 | Val Rel-L2: 2.426522e-01
# [deeponet_n50] Epoch  211/1000 | Train MSE(n): 2.371747e-02 | Val Rel-L2: 2.429703e-01
# [deeponet_n50] Epoch  212/1000 | Train MSE(n): 2.378607e-02 | Val Rel-L2: 2.433110e-01
# [deeponet_n50] Epoch  213/1000 | Train MSE(n): 2.402603e-02 | Val Rel-L2: 2.445705e-01
# [deeponet_n50] Epoch  214/1000 | Train MSE(n): 2.423802e-02 | Val Rel-L2: 2.446917e-01
# [deeponet_n50] Epoch  215/1000 | Train MSE(n): 2.432038e-02 | Val Rel-L2: 2.450468e-01
# [deeponet_n50] Epoch  216/1000 | Train MSE(n): 2.423180e-02 | Val Rel-L2: 2.443263e-01
# [deeponet_n50] Epoch  217/1000 | Train MSE(n): 2.399756e-02 | Val Rel-L2: 2.443126e-01
# [deeponet_n50] Epoch  218/1000 | Train MSE(n): 2.368872e-02 | Val Rel-L2: 2.434176e-01
# [deeponet_n50] Epoch  219/1000 | Train MSE(n): 2.339674e-02 | Val Rel-L2: 2.434204e-01
# [deeponet_n50] Epoch  220/1000 | Train MSE(n): 2.318244e-02 | Val Rel-L2: 2.432814e-01
# [deeponet_n50] Epoch  221/1000 | Train MSE(n): 2.307803e-02 | Val Rel-L2: 2.435149e-01
# [deeponet_n50] Epoch  222/1000 | Train MSE(n): 2.306806e-02 | Val Rel-L2: 2.438135e-01
# [deeponet_n50] Epoch  223/1000 | Train MSE(n): 2.314939e-02 | Val Rel-L2: 2.442684e-01
# [deeponet_n50] Epoch  224/1000 | Train MSE(n): 2.328418e-02 | Val Rel-L2: 2.445364e-01
# [deeponet_n50] Epoch  225/1000 | Train MSE(n): 2.337468e-02 | Val Rel-L2: 2.445298e-01
# [deeponet_n50] Epoch  226/1000 | Train MSE(n): 2.336724e-02 | Val Rel-L2: 2.441916e-01
# [deeponet_n50] Epoch  227/1000 | Train MSE(n): 2.311698e-02 | Val Rel-L2: 2.433651e-01
# [deeponet_n50] Epoch  228/1000 | Train MSE(n): 2.272933e-02 | Val Rel-L2: 2.424029e-01
# [deeponet_n50] Epoch  229/1000 | Train MSE(n): 2.234316e-02 | Val Rel-L2: 2.420777e-01
# [deeponet_n50] Epoch  230/1000 | Train MSE(n): 2.213379e-02 | Val Rel-L2: 2.421343e-01
# [deeponet_n50] Epoch  231/1000 | Train MSE(n): 2.213015e-02 | Val Rel-L2: 2.423014e-01
# [deeponet_n50] Epoch  232/1000 | Train MSE(n): 2.223364e-02 | Val Rel-L2: 2.426115e-01
# [deeponet_n50] Epoch  233/1000 | Train MSE(n): 2.231180e-02 | Val Rel-L2: 2.425893e-01
# [deeponet_n50] Epoch  234/1000 | Train MSE(n): 2.226538e-02 | Val Rel-L2: 2.422800e-01
# [deeponet_n50] Epoch  235/1000 | Train MSE(n): 2.210093e-02 | Val Rel-L2: 2.418825e-01
# [deeponet_n50] Epoch  236/1000 | Train MSE(n): 2.185575e-02 | Val Rel-L2: 2.415593e-01
# [deeponet_n50] Epoch  237/1000 | Train MSE(n): 2.162913e-02 | Val Rel-L2: 2.413099e-01
# [deeponet_n50] Epoch  238/1000 | Train MSE(n): 2.147751e-02 | Val Rel-L2: 2.413180e-01
# [deeponet_n50] Epoch  239/1000 | Train MSE(n): 2.141374e-02 | Val Rel-L2: 2.414872e-01
# [deeponet_n50] Epoch  240/1000 | Train MSE(n): 2.140887e-02 | Val Rel-L2: 2.415530e-01
# [deeponet_n50] Epoch  241/1000 | Train MSE(n): 2.143081e-02 | Val Rel-L2: 2.418817e-01
# [deeponet_n50] Epoch  242/1000 | Train MSE(n): 2.145515e-02 | Val Rel-L2: 2.419470e-01
# [deeponet_n50] Epoch  243/1000 | Train MSE(n): 2.149157e-02 | Val Rel-L2: 2.426518e-01
# [deeponet_n50] Epoch  244/1000 | Train MSE(n): 2.164635e-02 | Val Rel-L2: 2.439664e-01
# [deeponet_n50] Epoch  245/1000 | Train MSE(n): 2.242673e-02 | Val Rel-L2: 2.503263e-01
# [deeponet_n50] Epoch  246/1000 | Train MSE(n): 2.509138e-02 | Val Rel-L2: 2.677488e-01
# [deeponet_n50] Epoch  247/1000 | Train MSE(n): 3.388754e-02 | Val Rel-L2: 2.994364e-01
# [deeponet_n50] Epoch  248/1000 | Train MSE(n): 5.006248e-02 | Val Rel-L2: 3.203279e-01
# [deeponet_n50] Epoch  249/1000 | Train MSE(n): 6.300182e-02 | Val Rel-L2: 2.770321e-01
# [deeponet_n50] Epoch  250/1000 | Train MSE(n): 3.871069e-02 | Val Rel-L2: 2.586837e-01
# [deeponet_n50] Epoch  251/1000 | Train MSE(n): 2.979996e-02 | Val Rel-L2: 2.885045e-01
# [deeponet_n50] Epoch  252/1000 | Train MSE(n): 4.369677e-02 | Val Rel-L2: 2.632293e-01
# [deeponet_n50] Epoch  253/1000 | Train MSE(n): 3.188168e-02 | Val Rel-L2: 2.789373e-01
# [deeponet_n50] Epoch  254/1000 | Train MSE(n): 3.659046e-02 | Val Rel-L2: 2.584781e-01
# [deeponet_n50] Epoch  255/1000 | Train MSE(n): 3.139646e-02 | Val Rel-L2: 2.608271e-01
# [deeponet_n50] Epoch  256/1000 | Train MSE(n): 3.095567e-02 | Val Rel-L2: 2.624481e-01
# [deeponet_n50] Epoch  257/1000 | Train MSE(n): 3.032827e-02 | Val Rel-L2: 2.484522e-01
# [deeponet_n50] Epoch  258/1000 | Train MSE(n): 2.514697e-02 | Val Rel-L2: 2.593068e-01
# [deeponet_n50] Epoch  259/1000 | Train MSE(n): 3.085051e-02 | Val Rel-L2: 2.407575e-01
# [deeponet_n50] Epoch  260/1000 | Train MSE(n): 2.305886e-02 | Val Rel-L2: 2.607411e-01
# [deeponet_n50] Epoch  261/1000 | Train MSE(n): 3.001413e-02 | Val Rel-L2: 2.413829e-01
# [deeponet_n50] Epoch  262/1000 | Train MSE(n): 2.241575e-02 | Val Rel-L2: 2.530825e-01
# [deeponet_n50] Epoch  263/1000 | Train MSE(n): 2.725001e-02 | Val Rel-L2: 2.408590e-01
# [deeponet_n50] Epoch  264/1000 | Train MSE(n): 2.239863e-02 | Val Rel-L2: 2.480716e-01
# [deeponet_n50] Epoch  265/1000 | Train MSE(n): 2.506284e-02 | Val Rel-L2: 2.416824e-01
# [deeponet_n50] Epoch  266/1000 | Train MSE(n): 2.281545e-02 | Val Rel-L2: 2.428784e-01
# [deeponet_n50] Epoch  267/1000 | Train MSE(n): 2.359190e-02 | Val Rel-L2: 2.446367e-01
# [deeponet_n50] Epoch  268/1000 | Train MSE(n): 2.251933e-02 | Val Rel-L2: 2.441523e-01
# [deeponet_n50] Epoch  269/1000 | Train MSE(n): 2.226559e-02 | Val Rel-L2: 2.437542e-01
# [deeponet_n50] Epoch  270/1000 | Train MSE(n): 2.244433e-02 | Val Rel-L2: 2.409656e-01
# [deeponet_n50] Epoch  271/1000 | Train MSE(n): 2.130831e-02 | Val Rel-L2: 2.459823e-01
# [deeponet_n50] Epoch  272/1000 | Train MSE(n): 2.225394e-02 | Val Rel-L2: 2.412964e-01
# [deeponet_n50] Epoch  273/1000 | Train MSE(n): 2.054525e-02 | Val Rel-L2: 2.438498e-01
# [deeponet_n50] Epoch  274/1000 | Train MSE(n): 2.185146e-02 | Val Rel-L2: 2.405412e-01
# [deeponet_n50] Epoch  275/1000 | Train MSE(n): 2.024882e-02 | Val Rel-L2: 2.436002e-01
# [deeponet_n50] Epoch  276/1000 | Train MSE(n): 2.119279e-02 | Val Rel-L2: 2.401313e-01
# [deeponet_n50] Epoch  277/1000 | Train MSE(n): 2.019492e-02 | Val Rel-L2: 2.406677e-01
# [deeponet_n50] Epoch  278/1000 | Train MSE(n): 2.055610e-02 | Val Rel-L2: 2.399591e-01
# [deeponet_n50] Epoch  279/1000 | Train MSE(n): 2.005911e-02 | Val Rel-L2: 2.395828e-01
# [deeponet_n50] Epoch  280/1000 | Train MSE(n): 2.006411e-02 | Val Rel-L2: 2.391879e-01
# [deeponet_n50] Epoch  281/1000 | Train MSE(n): 2.003423e-02 | Val Rel-L2: 2.380068e-01
# [deeponet_n50] Epoch  282/1000 | Train MSE(n): 1.954098e-02 | Val Rel-L2: 2.395778e-01
# [deeponet_n50] Epoch  283/1000 | Train MSE(n): 1.995959e-02 | Val Rel-L2: 2.371180e-01
# [deeponet_n50] Epoch  284/1000 | Train MSE(n): 1.922134e-02 | Val Rel-L2: 2.381043e-01
# [deeponet_n50] Epoch  285/1000 | Train MSE(n): 1.964445e-02 | Val Rel-L2: 2.374702e-01
# [deeponet_n50] Epoch  286/1000 | Train MSE(n): 1.915595e-02 | Val Rel-L2: 2.378099e-01
# [deeponet_n50] Epoch  287/1000 | Train MSE(n): 1.921059e-02 | Val Rel-L2: 2.370186e-01
# [deeponet_n50] Epoch  288/1000 | Train MSE(n): 1.915114e-02 | Val Rel-L2: 2.358538e-01
# [deeponet_n50] Epoch  289/1000 | Train MSE(n): 1.887379e-02 | Val Rel-L2: 2.365826e-01
# [deeponet_n50] Epoch  290/1000 | Train MSE(n): 1.905700e-02 | Val Rel-L2: 2.357198e-01
# [deeponet_n50] Epoch  291/1000 | Train MSE(n): 1.866184e-02 | Val Rel-L2: 2.363706e-01
# [deeponet_n50] Epoch  292/1000 | Train MSE(n): 1.886160e-02 | Val Rel-L2: 2.355787e-01
# [deeponet_n50] Epoch  293/1000 | Train MSE(n): 1.856129e-02 | Val Rel-L2: 2.352767e-01
# [deeponet_n50] Epoch  294/1000 | Train MSE(n): 1.860637e-02 | Val Rel-L2: 2.351023e-01
# [deeponet_n50] Epoch  295/1000 | Train MSE(n): 1.852242e-02 | Val Rel-L2: 2.352818e-01
# [deeponet_n50] Epoch  296/1000 | Train MSE(n): 1.836381e-02 | Val Rel-L2: 2.355899e-01
# [deeponet_n50] Epoch  297/1000 | Train MSE(n): 1.843709e-02 | Val Rel-L2: 2.344824e-01
# [deeponet_n50] Epoch  298/1000 | Train MSE(n): 1.823475e-02 | Val Rel-L2: 2.344868e-01
# [deeponet_n50] Epoch  299/1000 | Train MSE(n): 1.824473e-02 | Val Rel-L2: 2.350861e-01
# [deeponet_n50] Epoch  300/1000 | Train MSE(n): 1.818015e-02 | Val Rel-L2: 2.349021e-01
# [deeponet_n50] Epoch  301/1000 | Train MSE(n): 1.805922e-02 | Val Rel-L2: 2.343646e-01
# [deeponet_n50] Epoch  302/1000 | Train MSE(n): 1.809022e-02 | Val Rel-L2: 2.338827e-01
# [deeponet_n50] Epoch  303/1000 | Train MSE(n): 1.794606e-02 | Val Rel-L2: 2.343717e-01
# [deeponet_n50] Epoch  304/1000 | Train MSE(n): 1.795704e-02 | Val Rel-L2: 2.341267e-01
# [deeponet_n50] Epoch  305/1000 | Train MSE(n): 1.787800e-02 | Val Rel-L2: 2.336292e-01
# [deeponet_n50] Epoch  306/1000 | Train MSE(n): 1.780159e-02 | Val Rel-L2: 2.336839e-01
# [deeponet_n50] Epoch  307/1000 | Train MSE(n): 1.780752e-02 | Val Rel-L2: 2.335492e-01
# [deeponet_n50] Epoch  308/1000 | Train MSE(n): 1.769030e-02 | Val Rel-L2: 2.334946e-01
# [deeponet_n50] Epoch  309/1000 | Train MSE(n): 1.767928e-02 | Val Rel-L2: 2.332148e-01
# [deeponet_n50] Epoch  310/1000 | Train MSE(n): 1.762548e-02 | Val Rel-L2: 2.329118e-01
# [deeponet_n50] Epoch  311/1000 | Train MSE(n): 1.755094e-02 | Val Rel-L2: 2.330251e-01
# [deeponet_n50] Epoch  312/1000 | Train MSE(n): 1.753455e-02 | Val Rel-L2: 2.329084e-01
# [deeponet_n50] Epoch  313/1000 | Train MSE(n): 1.745763e-02 | Val Rel-L2: 2.326585e-01
# [deeponet_n50] Epoch  314/1000 | Train MSE(n): 1.741713e-02 | Val Rel-L2: 2.325855e-01
# [deeponet_n50] Epoch  315/1000 | Train MSE(n): 1.737845e-02 | Val Rel-L2: 2.326283e-01
# [deeponet_n50] Epoch  316/1000 | Train MSE(n): 1.730683e-02 | Val Rel-L2: 2.325790e-01
# [deeponet_n50] Epoch  317/1000 | Train MSE(n): 1.727858e-02 | Val Rel-L2: 2.321723e-01
# [deeponet_n50] Epoch  318/1000 | Train MSE(n): 1.721888e-02 | Val Rel-L2: 2.319145e-01
# [deeponet_n50] Epoch  319/1000 | Train MSE(n): 1.716002e-02 | Val Rel-L2: 2.319049e-01
# [deeponet_n50] Epoch  320/1000 | Train MSE(n): 1.712391e-02 | Val Rel-L2: 2.317823e-01
# [deeponet_n50] Epoch  321/1000 | Train MSE(n): 1.705921e-02 | Val Rel-L2: 2.315320e-01
# [deeponet_n50] Epoch  322/1000 | Train MSE(n): 1.700839e-02 | Val Rel-L2: 2.313145e-01
# [deeponet_n50] Epoch  323/1000 | Train MSE(n): 1.696085e-02 | Val Rel-L2: 2.311588e-01
# [deeponet_n50] Epoch  324/1000 | Train MSE(n): 1.689701e-02 | Val Rel-L2: 2.310344e-01
# [deeponet_n50] Epoch  325/1000 | Train MSE(n): 1.684493e-02 | Val Rel-L2: 2.309246e-01
# [deeponet_n50] Epoch  326/1000 | Train MSE(n): 1.679061e-02 | Val Rel-L2: 2.307239e-01
# [deeponet_n50] Epoch  327/1000 | Train MSE(n): 1.672447e-02 | Val Rel-L2: 2.305532e-01
# [deeponet_n50] Epoch  328/1000 | Train MSE(n): 1.667356e-02 | Val Rel-L2: 2.303827e-01
# [deeponet_n50] Epoch  329/1000 | Train MSE(n): 1.661081e-02 | Val Rel-L2: 2.301405e-01
# [deeponet_n50] Epoch  330/1000 | Train MSE(n): 1.654573e-02 | Val Rel-L2: 2.299331e-01
# [deeponet_n50] Epoch  331/1000 | Train MSE(n): 1.648770e-02 | Val Rel-L2: 2.297342e-01
# [deeponet_n50] Epoch  332/1000 | Train MSE(n): 1.642371e-02 | Val Rel-L2: 2.293911e-01
# [deeponet_n50] Epoch  333/1000 | Train MSE(n): 1.635562e-02 | Val Rel-L2: 2.291080e-01
# [deeponet_n50] Epoch  334/1000 | Train MSE(n): 1.629527e-02 | Val Rel-L2: 2.289688e-01
# [deeponet_n50] Epoch  335/1000 | Train MSE(n): 1.622849e-02 | Val Rel-L2: 2.286784e-01
# [deeponet_n50] Epoch  336/1000 | Train MSE(n): 1.616061e-02 | Val Rel-L2: 2.283271e-01
# [deeponet_n50] Epoch  337/1000 | Train MSE(n): 1.609584e-02 | Val Rel-L2: 2.280884e-01
# [deeponet_n50] Epoch  338/1000 | Train MSE(n): 1.602914e-02 | Val Rel-L2: 2.278344e-01
# [deeponet_n50] Epoch  339/1000 | Train MSE(n): 1.596161e-02 | Val Rel-L2: 2.274907e-01
# [deeponet_n50] Epoch  340/1000 | Train MSE(n): 1.589575e-02 | Val Rel-L2: 2.271891e-01
# [deeponet_n50] Epoch  341/1000 | Train MSE(n): 1.582926e-02 | Val Rel-L2: 2.269378e-01
# [deeponet_n50] Epoch  342/1000 | Train MSE(n): 1.576042e-02 | Val Rel-L2: 2.266253e-01
# [deeponet_n50] Epoch  343/1000 | Train MSE(n): 1.569471e-02 | Val Rel-L2: 2.263214e-01
# [deeponet_n50] Epoch  344/1000 | Train MSE(n): 1.562952e-02 | Val Rel-L2: 2.261450e-01
# [deeponet_n50] Epoch  345/1000 | Train MSE(n): 1.556356e-02 | Val Rel-L2: 2.258108e-01
# [deeponet_n50] Epoch  346/1000 | Train MSE(n): 1.549743e-02 | Val Rel-L2: 2.254263e-01
# [deeponet_n50] Epoch  347/1000 | Train MSE(n): 1.543440e-02 | Val Rel-L2: 2.251245e-01
# [deeponet_n50] Epoch  348/1000 | Train MSE(n): 1.537190e-02 | Val Rel-L2: 2.249115e-01
# [deeponet_n50] Epoch  349/1000 | Train MSE(n): 1.531005e-02 | Val Rel-L2: 2.247081e-01
# [deeponet_n50] Epoch  350/1000 | Train MSE(n): 1.524961e-02 | Val Rel-L2: 2.244289e-01
# [deeponet_n50] Epoch  351/1000 | Train MSE(n): 1.518957e-02 | Val Rel-L2: 2.242686e-01
# [deeponet_n50] Epoch  352/1000 | Train MSE(n): 1.512899e-02 | Val Rel-L2: 2.242111e-01
# [deeponet_n50] Epoch  353/1000 | Train MSE(n): 1.506986e-02 | Val Rel-L2: 2.241113e-01
# [deeponet_n50] Epoch  354/1000 | Train MSE(n): 1.501226e-02 | Val Rel-L2: 2.239826e-01
# [deeponet_n50] Epoch  355/1000 | Train MSE(n): 1.495545e-02 | Val Rel-L2: 2.238434e-01
# [deeponet_n50] Epoch  356/1000 | Train MSE(n): 1.489951e-02 | Val Rel-L2: 2.237555e-01
# [deeponet_n50] Epoch  357/1000 | Train MSE(n): 1.484428e-02 | Val Rel-L2: 2.236740e-01
# [deeponet_n50] Epoch  358/1000 | Train MSE(n): 1.478907e-02 | Val Rel-L2: 2.236152e-01
# [deeponet_n50] Epoch  359/1000 | Train MSE(n): 1.473483e-02 | Val Rel-L2: 2.235510e-01
# [deeponet_n50] Epoch  360/1000 | Train MSE(n): 1.468177e-02 | Val Rel-L2: 2.234522e-01
# [deeponet_n50] Epoch  361/1000 | Train MSE(n): 1.463029e-02 | Val Rel-L2: 2.234615e-01
# [deeponet_n50] Epoch  362/1000 | Train MSE(n): 1.457983e-02 | Val Rel-L2: 2.235414e-01
# [deeponet_n50] Epoch  363/1000 | Train MSE(n): 1.453012e-02 | Val Rel-L2: 2.234196e-01
# [deeponet_n50] Epoch  364/1000 | Train MSE(n): 1.448071e-02 | Val Rel-L2: 2.233166e-01
# [deeponet_n50] Epoch  365/1000 | Train MSE(n): 1.443220e-02 | Val Rel-L2: 2.233389e-01
# [deeponet_n50] Epoch  366/1000 | Train MSE(n): 1.438415e-02 | Val Rel-L2: 2.234157e-01
# [deeponet_n50] Epoch  367/1000 | Train MSE(n): 1.433537e-02 | Val Rel-L2: 2.235437e-01
# [deeponet_n50] Epoch  368/1000 | Train MSE(n): 1.428939e-02 | Val Rel-L2: 2.235258e-01
# [deeponet_n50] Epoch  369/1000 | Train MSE(n): 1.424149e-02 | Val Rel-L2: 2.234668e-01
# [deeponet_n50] Epoch  370/1000 | Train MSE(n): 1.419391e-02 | Val Rel-L2: 2.234193e-01
# [deeponet_n50] Epoch  371/1000 | Train MSE(n): 1.414877e-02 | Val Rel-L2: 2.234090e-01
# [deeponet_n50] Epoch  372/1000 | Train MSE(n): 1.410392e-02 | Val Rel-L2: 2.234567e-01
# [deeponet_n50] Epoch  373/1000 | Train MSE(n): 1.405889e-02 | Val Rel-L2: 2.233563e-01
# [deeponet_n50] Epoch  374/1000 | Train MSE(n): 1.401359e-02 | Val Rel-L2: 2.231816e-01
# [deeponet_n50] Epoch  375/1000 | Train MSE(n): 1.396807e-02 | Val Rel-L2: 2.231175e-01
# [deeponet_n50] Epoch  376/1000 | Train MSE(n): 1.392468e-02 | Val Rel-L2: 2.229200e-01
# [deeponet_n50] Epoch  377/1000 | Train MSE(n): 1.388409e-02 | Val Rel-L2: 2.230507e-01
# [deeponet_n50] Epoch  378/1000 | Train MSE(n): 1.384485e-02 | Val Rel-L2: 2.229796e-01
# [deeponet_n50] Epoch  379/1000 | Train MSE(n): 1.380813e-02 | Val Rel-L2: 2.230574e-01
# [deeponet_n50] Epoch  380/1000 | Train MSE(n): 1.377367e-02 | Val Rel-L2: 2.229591e-01
# [deeponet_n50] Epoch  381/1000 | Train MSE(n): 1.374525e-02 | Val Rel-L2: 2.229897e-01
# [deeponet_n50] Epoch  382/1000 | Train MSE(n): 1.372388e-02 | Val Rel-L2: 2.231050e-01
# [deeponet_n50] Epoch  383/1000 | Train MSE(n): 1.371016e-02 | Val Rel-L2: 2.230116e-01
# [deeponet_n50] Epoch  384/1000 | Train MSE(n): 1.370589e-02 | Val Rel-L2: 2.233911e-01
# [deeponet_n50] Epoch  385/1000 | Train MSE(n): 1.371516e-02 | Val Rel-L2: 2.231097e-01
# [deeponet_n50] Epoch  386/1000 | Train MSE(n): 1.373793e-02 | Val Rel-L2: 2.236609e-01
# [deeponet_n50] Epoch  387/1000 | Train MSE(n): 1.379315e-02 | Val Rel-L2: 2.232190e-01
# [deeponet_n50] Epoch  388/1000 | Train MSE(n): 1.386930e-02 | Val Rel-L2: 2.242393e-01
# [deeponet_n50] Epoch  389/1000 | Train MSE(n): 1.397512e-02 | Val Rel-L2: 2.237488e-01
# [deeponet_n50] Epoch  390/1000 | Train MSE(n): 1.411137e-02 | Val Rel-L2: 2.252972e-01
# [deeponet_n50] Epoch  391/1000 | Train MSE(n): 1.430565e-02 | Val Rel-L2: 2.246324e-01
# [deeponet_n50] Epoch  392/1000 | Train MSE(n): 1.453825e-02 | Val Rel-L2: 2.265088e-01
# [deeponet_n50] Epoch  393/1000 | Train MSE(n): 1.482675e-02 | Val Rel-L2: 2.258021e-01
# [deeponet_n50] Epoch  394/1000 | Train MSE(n): 1.512805e-02 | Val Rel-L2: 2.280858e-01
# [deeponet_n50] Epoch  395/1000 | Train MSE(n): 1.543784e-02 | Val Rel-L2: 2.267239e-01
# [deeponet_n50] Epoch  396/1000 | Train MSE(n): 1.557101e-02 | Val Rel-L2: 2.284997e-01
# [deeponet_n50] Epoch  397/1000 | Train MSE(n): 1.546524e-02 | Val Rel-L2: 2.256322e-01
# [deeponet_n50] Epoch  398/1000 | Train MSE(n): 1.503799e-02 | Val Rel-L2: 2.259040e-01
# [deeponet_n50] Epoch  399/1000 | Train MSE(n): 1.438366e-02 | Val Rel-L2: 2.227202e-01
# [deeponet_n50] Epoch  400/1000 | Train MSE(n): 1.368438e-02 | Val Rel-L2: 2.222529e-01
# [deeponet_n50] Epoch  401/1000 | Train MSE(n): 1.317275e-02 | Val Rel-L2: 2.210792e-01
# [deeponet_n50] Epoch  402/1000 | Train MSE(n): 1.295903e-02 | Val Rel-L2: 2.214414e-01
# [deeponet_n50] Epoch  403/1000 | Train MSE(n): 1.303327e-02 | Val Rel-L2: 2.224246e-01
# [deeponet_n50] Epoch  404/1000 | Train MSE(n): 1.327918e-02 | Val Rel-L2: 2.225546e-01
# [deeponet_n50] Epoch  405/1000 | Train MSE(n): 1.354682e-02 | Val Rel-L2: 2.241854e-01
# [deeponet_n50] Epoch  406/1000 | Train MSE(n): 1.375029e-02 | Val Rel-L2: 2.229424e-01
# [deeponet_n50] Epoch  407/1000 | Train MSE(n): 1.382197e-02 | Val Rel-L2: 2.243820e-01
# [deeponet_n50] Epoch  408/1000 | Train MSE(n): 1.377393e-02 | Val Rel-L2: 2.219191e-01
# [deeponet_n50] Epoch  409/1000 | Train MSE(n): 1.359382e-02 | Val Rel-L2: 2.231827e-01
# [deeponet_n50] Epoch  410/1000 | Train MSE(n): 1.335653e-02 | Val Rel-L2: 2.208222e-01
# [deeponet_n50] Epoch  411/1000 | Train MSE(n): 1.312561e-02 | Val Rel-L2: 2.222268e-01
# [deeponet_n50] Epoch  412/1000 | Train MSE(n): 1.296362e-02 | Val Rel-L2: 2.205756e-01
# [deeponet_n50] Epoch  413/1000 | Train MSE(n): 1.288117e-02 | Val Rel-L2: 2.220080e-01
# [deeponet_n50] Epoch  414/1000 | Train MSE(n): 1.286294e-02 | Val Rel-L2: 2.210389e-01
# [deeponet_n50] Epoch  415/1000 | Train MSE(n): 1.291610e-02 | Val Rel-L2: 2.221116e-01
# [deeponet_n50] Epoch  416/1000 | Train MSE(n): 1.299505e-02 | Val Rel-L2: 2.215755e-01
# [deeponet_n50] Epoch  417/1000 | Train MSE(n): 1.307691e-02 | Val Rel-L2: 2.222316e-01
# [deeponet_n50] Epoch  418/1000 | Train MSE(n): 1.311510e-02 | Val Rel-L2: 2.219304e-01
# [deeponet_n50] Epoch  419/1000 | Train MSE(n): 1.311388e-02 | Val Rel-L2: 2.223135e-01
# [deeponet_n50] Epoch  420/1000 | Train MSE(n): 1.305181e-02 | Val Rel-L2: 2.216461e-01
# [deeponet_n50] Epoch  421/1000 | Train MSE(n): 1.293507e-02 | Val Rel-L2: 2.214134e-01
# [deeponet_n50] Epoch  422/1000 | Train MSE(n): 1.277995e-02 | Val Rel-L2: 2.209890e-01
# [deeponet_n50] Epoch  423/1000 | Train MSE(n): 1.261289e-02 | Val Rel-L2: 2.206296e-01
# [deeponet_n50] Epoch  424/1000 | Train MSE(n): 1.246320e-02 | Val Rel-L2: 2.202378e-01
# [deeponet_n50] Epoch  425/1000 | Train MSE(n): 1.235307e-02 | Val Rel-L2: 2.201381e-01
# [deeponet_n50] Epoch  426/1000 | Train MSE(n): 1.228566e-02 | Val Rel-L2: 2.202606e-01
# [deeponet_n50] Epoch  427/1000 | Train MSE(n): 1.225793e-02 | Val Rel-L2: 2.202074e-01
# [deeponet_n50] Epoch  428/1000 | Train MSE(n): 1.226276e-02 | Val Rel-L2: 2.204691e-01
# [deeponet_n50] Epoch  429/1000 | Train MSE(n): 1.228906e-02 | Val Rel-L2: 2.200137e-01
# [deeponet_n50] Epoch  430/1000 | Train MSE(n): 1.233156e-02 | Val Rel-L2: 2.206108e-01
# [deeponet_n50] Epoch  431/1000 | Train MSE(n): 1.238661e-02 | Val Rel-L2: 2.203153e-01
# [deeponet_n50] Epoch  432/1000 | Train MSE(n): 1.246583e-02 | Val Rel-L2: 2.212576e-01
# [deeponet_n50] Epoch  433/1000 | Train MSE(n): 1.257200e-02 | Val Rel-L2: 2.210926e-01
# [deeponet_n50] Epoch  434/1000 | Train MSE(n): 1.271718e-02 | Val Rel-L2: 2.225371e-01
# [deeponet_n50] Epoch  435/1000 | Train MSE(n): 1.290044e-02 | Val Rel-L2: 2.222128e-01
# [deeponet_n50] Epoch  436/1000 | Train MSE(n): 1.313027e-02 | Val Rel-L2: 2.238894e-01
# [deeponet_n50] Epoch  437/1000 | Train MSE(n): 1.334282e-02 | Val Rel-L2: 2.230486e-01
# [deeponet_n50] Epoch  438/1000 | Train MSE(n): 1.352517e-02 | Val Rel-L2: 2.242269e-01
# [deeponet_n50] Epoch  439/1000 | Train MSE(n): 1.349402e-02 | Val Rel-L2: 2.224163e-01
# [deeponet_n50] Epoch  440/1000 | Train MSE(n): 1.329014e-02 | Val Rel-L2: 2.222289e-01
# [deeponet_n50] Epoch  441/1000 | Train MSE(n): 1.281676e-02 | Val Rel-L2: 2.201563e-01
# [deeponet_n50] Epoch  442/1000 | Train MSE(n): 1.232436e-02 | Val Rel-L2: 2.194724e-01
# [deeponet_n50] Epoch  443/1000 | Train MSE(n): 1.197572e-02 | Val Rel-L2: 2.196738e-01
# [deeponet_n50] Epoch  444/1000 | Train MSE(n): 1.190868e-02 | Val Rel-L2: 2.191543e-01
# [deeponet_n50] Epoch  445/1000 | Train MSE(n): 1.207751e-02 | Val Rel-L2: 2.215579e-01
# [deeponet_n50] Epoch  446/1000 | Train MSE(n): 1.232054e-02 | Val Rel-L2: 2.200259e-01
# [deeponet_n50] Epoch  447/1000 | Train MSE(n): 1.250496e-02 | Val Rel-L2: 2.223834e-01
# [deeponet_n50] Epoch  448/1000 | Train MSE(n): 1.249522e-02 | Val Rel-L2: 2.194270e-01
# [deeponet_n50] Epoch  449/1000 | Train MSE(n): 1.240673e-02 | Val Rel-L2: 2.217539e-01
# [deeponet_n50] Epoch  450/1000 | Train MSE(n): 1.232552e-02 | Val Rel-L2: 2.189814e-01
# [deeponet_n50] Epoch  451/1000 | Train MSE(n): 1.247027e-02 | Val Rel-L2: 2.230776e-01
# [deeponet_n50] Epoch  452/1000 | Train MSE(n): 1.298983e-02 | Val Rel-L2: 2.221146e-01
# [deeponet_n50] Epoch  453/1000 | Train MSE(n): 1.398242e-02 | Val Rel-L2: 2.299531e-01
# [deeponet_n50] Epoch  454/1000 | Train MSE(n): 1.572054e-02 | Val Rel-L2: 2.306030e-01
# [deeponet_n50] Epoch  455/1000 | Train MSE(n): 1.802282e-02 | Val Rel-L2: 2.427878e-01
# [deeponet_n50] Epoch  456/1000 | Train MSE(n): 2.101562e-02 | Val Rel-L2: 2.392977e-01
# [deeponet_n50] Epoch  457/1000 | Train MSE(n): 2.248340e-02 | Val Rel-L2: 2.445946e-01
# [deeponet_n50] Epoch  458/1000 | Train MSE(n): 2.133184e-02 | Val Rel-L2: 2.264918e-01
# [deeponet_n50] Epoch  459/1000 | Train MSE(n): 1.653487e-02 | Val Rel-L2: 2.202573e-01
# [deeponet_n50] Epoch  460/1000 | Train MSE(n): 1.228087e-02 | Val Rel-L2: 2.195816e-01
# [deeponet_n50] Epoch  461/1000 | Train MSE(n): 1.226572e-02 | Val Rel-L2: 2.240193e-01
# [deeponet_n50] Epoch  462/1000 | Train MSE(n): 1.524031e-02 | Val Rel-L2: 2.318058e-01
# [deeponet_n50] Epoch  463/1000 | Train MSE(n): 1.668346e-02 | Val Rel-L2: 2.224719e-01
# [deeponet_n50] Epoch  464/1000 | Train MSE(n): 1.448680e-02 | Val Rel-L2: 2.185832e-01
# [deeponet_n50] Epoch  465/1000 | Train MSE(n): 1.187871e-02 | Val Rel-L2: 2.199945e-01
# [deeponet_n50] Epoch  466/1000 | Train MSE(n): 1.209885e-02 | Val Rel-L2: 2.202678e-01
# [deeponet_n50] Epoch  467/1000 | Train MSE(n): 1.392938e-02 | Val Rel-L2: 2.253194e-01
# [deeponet_n50] Epoch  468/1000 | Train MSE(n): 1.420091e-02 | Val Rel-L2: 2.182710e-01
# [deeponet_n50] Epoch  469/1000 | Train MSE(n): 1.253475e-02 | Val Rel-L2: 2.167596e-01
# [deeponet_n50] Epoch  470/1000 | Train MSE(n): 1.156003e-02 | Val Rel-L2: 2.201227e-01
# [deeponet_n50] Epoch  471/1000 | Train MSE(n): 1.231002e-02 | Val Rel-L2: 2.180740e-01
# [deeponet_n50] Epoch  472/1000 | Train MSE(n): 1.309072e-02 | Val Rel-L2: 2.200558e-01
# [deeponet_n50] Epoch  473/1000 | Train MSE(n): 1.266122e-02 | Val Rel-L2: 2.162320e-01
# [deeponet_n50] Epoch  474/1000 | Train MSE(n): 1.170187e-02 | Val Rel-L2: 2.155034e-01
# [deeponet_n50] Epoch  475/1000 | Train MSE(n): 1.157574e-02 | Val Rel-L2: 2.197863e-01
# [deeponet_n50] Epoch  476/1000 | Train MSE(n): 1.211120e-02 | Val Rel-L2: 2.163363e-01
# [deeponet_n50] Epoch  477/1000 | Train MSE(n): 1.222933e-02 | Val Rel-L2: 2.171132e-01
# [deeponet_n50] Epoch  478/1000 | Train MSE(n): 1.174658e-02 | Val Rel-L2: 2.166747e-01
# [deeponet_n50] Epoch  479/1000 | Train MSE(n): 1.141027e-02 | Val Rel-L2: 2.151148e-01
# [deeponet_n50] Epoch  480/1000 | Train MSE(n): 1.158273e-02 | Val Rel-L2: 2.179576e-01
# [deeponet_n50] Epoch  481/1000 | Train MSE(n): 1.175988e-02 | Val Rel-L2: 2.152832e-01
# [deeponet_n50] Epoch  482/1000 | Train MSE(n): 1.158379e-02 | Val Rel-L2: 2.152091e-01
# [deeponet_n50] Epoch  483/1000 | Train MSE(n): 1.130645e-02 | Val Rel-L2: 2.161372e-01
# [deeponet_n50] Epoch  484/1000 | Train MSE(n): 1.129602e-02 | Val Rel-L2: 2.144267e-01
# [deeponet_n50] Epoch  485/1000 | Train MSE(n): 1.145779e-02 | Val Rel-L2: 2.165306e-01
# [deeponet_n50] Epoch  486/1000 | Train MSE(n): 1.142771e-02 | Val Rel-L2: 2.143083e-01
# [deeponet_n50] Epoch  487/1000 | Train MSE(n): 1.120848e-02 | Val Rel-L2: 2.144548e-01
# [deeponet_n50] Epoch  488/1000 | Train MSE(n): 1.106474e-02 | Val Rel-L2: 2.156269e-01
# [deeponet_n50] Epoch  489/1000 | Train MSE(n): 1.115372e-02 | Val Rel-L2: 2.139688e-01
# [deeponet_n50] Epoch  490/1000 | Train MSE(n): 1.127826e-02 | Val Rel-L2: 2.157070e-01
# [deeponet_n50] Epoch  491/1000 | Train MSE(n): 1.123676e-02 | Val Rel-L2: 2.134115e-01
# [deeponet_n50] Epoch  492/1000 | Train MSE(n): 1.104299e-02 | Val Rel-L2: 2.137093e-01
# [deeponet_n50] Epoch  493/1000 | Train MSE(n): 1.090240e-02 | Val Rel-L2: 2.142672e-01
# [deeponet_n50] Epoch  494/1000 | Train MSE(n): 1.093436e-02 | Val Rel-L2: 2.135171e-01
# [deeponet_n50] Epoch  495/1000 | Train MSE(n): 1.103476e-02 | Val Rel-L2: 2.151579e-01
# [deeponet_n50] Epoch  496/1000 | Train MSE(n): 1.105447e-02 | Val Rel-L2: 2.133854e-01
# [deeponet_n50] Epoch  497/1000 | Train MSE(n): 1.095782e-02 | Val Rel-L2: 2.142059e-01
# [deeponet_n50] Epoch  498/1000 | Train MSE(n): 1.084240e-02 | Val Rel-L2: 2.137258e-01
# [deeponet_n50] Epoch  499/1000 | Train MSE(n): 1.079467e-02 | Val Rel-L2: 2.134444e-01
# [deeponet_n50] Epoch  500/1000 | Train MSE(n): 1.081521e-02 | Val Rel-L2: 2.143409e-01
# [deeponet_n50] Epoch  501/1000 | Train MSE(n): 1.082988e-02 | Val Rel-L2: 2.134956e-01
# [deeponet_n50] Epoch  502/1000 | Train MSE(n): 1.079833e-02 | Val Rel-L2: 2.140926e-01
# [deeponet_n50] Epoch  503/1000 | Train MSE(n): 1.074024e-02 | Val Rel-L2: 2.132249e-01
# [deeponet_n50] Epoch  504/1000 | Train MSE(n): 1.070576e-02 | Val Rel-L2: 2.133180e-01
# [deeponet_n50] Epoch  505/1000 | Train MSE(n): 1.070911e-02 | Val Rel-L2: 2.134025e-01
# [deeponet_n50] Epoch  506/1000 | Train MSE(n): 1.072328e-02 | Val Rel-L2: 2.131269e-01
# [deeponet_n50] Epoch  507/1000 | Train MSE(n): 1.071853e-02 | Val Rel-L2: 2.133455e-01
# [deeponet_n50] Epoch  508/1000 | Train MSE(n): 1.068059e-02 | Val Rel-L2: 2.133088e-01
# [deeponet_n50] Epoch  509/1000 | Train MSE(n): 1.063301e-02 | Val Rel-L2: 2.129746e-01
# [deeponet_n50] Epoch  510/1000 | Train MSE(n): 1.059765e-02 | Val Rel-L2: 2.134728e-01
# [deeponet_n50] Epoch  511/1000 | Train MSE(n): 1.058599e-02 | Val Rel-L2: 2.128912e-01
# [deeponet_n50] Epoch  512/1000 | Train MSE(n): 1.059094e-02 | Val Rel-L2: 2.137176e-01
# [deeponet_n50] Epoch  513/1000 | Train MSE(n): 1.060015e-02 | Val Rel-L2: 2.129966e-01
# [deeponet_n50] Epoch  514/1000 | Train MSE(n): 1.060646e-02 | Val Rel-L2: 2.141190e-01
# [deeponet_n50] Epoch  515/1000 | Train MSE(n): 1.062258e-02 | Val Rel-L2: 2.132300e-01
# [deeponet_n50] Epoch  516/1000 | Train MSE(n): 1.067652e-02 | Val Rel-L2: 2.146001e-01
# [deeponet_n50] Epoch  517/1000 | Train MSE(n): 1.079711e-02 | Val Rel-L2: 2.139974e-01
# [deeponet_n50] Epoch  518/1000 | Train MSE(n): 1.106549e-02 | Val Rel-L2: 2.167620e-01
# [deeponet_n50] Epoch  519/1000 | Train MSE(n): 1.156314e-02 | Val Rel-L2: 2.175452e-01
# [deeponet_n50] Epoch  520/1000 | Train MSE(n): 1.248741e-02 | Val Rel-L2: 2.234535e-01
# [deeponet_n50] Epoch  521/1000 | Train MSE(n): 1.387608e-02 | Val Rel-L2: 2.255792e-01
# [deeponet_n50] Epoch  522/1000 | Train MSE(n): 1.574272e-02 | Val Rel-L2: 2.304662e-01
# [deeponet_n50] Epoch  523/1000 | Train MSE(n): 1.646720e-02 | Val Rel-L2: 2.241239e-01
# [deeponet_n50] Epoch  524/1000 | Train MSE(n): 1.568755e-02 | Val Rel-L2: 2.196988e-01
# [deeponet_n50] Epoch  525/1000 | Train MSE(n): 1.256325e-02 | Val Rel-L2: 2.127825e-01
# [deeponet_n50] Epoch  526/1000 | Train MSE(n): 1.071997e-02 | Val Rel-L2: 2.137073e-01
# [deeponet_n50] Epoch  527/1000 | Train MSE(n): 1.115452e-02 | Val Rel-L2: 2.203403e-01
# [deeponet_n50] Epoch  528/1000 | Train MSE(n): 1.254534e-02 | Val Rel-L2: 2.183667e-01
# [deeponet_n50] Epoch  529/1000 | Train MSE(n): 1.293507e-02 | Val Rel-L2: 2.165685e-01
# [deeponet_n50] Epoch  530/1000 | Train MSE(n): 1.129052e-02 | Val Rel-L2: 2.139685e-01
# [deeponet_n50] Epoch  531/1000 | Train MSE(n): 1.037747e-02 | Val Rel-L2: 2.136874e-01
# [deeponet_n50] Epoch  532/1000 | Train MSE(n): 1.129732e-02 | Val Rel-L2: 2.173299e-01
# [deeponet_n50] Epoch  533/1000 | Train MSE(n): 1.189497e-02 | Val Rel-L2: 2.132558e-01
# [deeponet_n50] Epoch  534/1000 | Train MSE(n): 1.112983e-02 | Val Rel-L2: 2.130297e-01
# [deeponet_n50] Epoch  535/1000 | Train MSE(n): 1.033425e-02 | Val Rel-L2: 2.145584e-01
# [deeponet_n50] Epoch  536/1000 | Train MSE(n): 1.071350e-02 | Val Rel-L2: 2.141037e-01
# [deeponet_n50] Epoch  537/1000 | Train MSE(n): 1.125993e-02 | Val Rel-L2: 2.161809e-01
# [deeponet_n50] Epoch  538/1000 | Train MSE(n): 1.089462e-02 | Val Rel-L2: 2.122131e-01
# [deeponet_n50] Epoch  539/1000 | Train MSE(n): 1.029506e-02 | Val Rel-L2: 2.115986e-01
# [deeponet_n50] Epoch  540/1000 | Train MSE(n): 1.030127e-02 | Val Rel-L2: 2.146302e-01
# [deeponet_n50] Epoch  541/1000 | Train MSE(n): 1.073860e-02 | Val Rel-L2: 2.116472e-01
# [deeponet_n50] Epoch  542/1000 | Train MSE(n): 1.071719e-02 | Val Rel-L2: 2.120326e-01
# [deeponet_n50] Epoch  543/1000 | Train MSE(n): 1.024045e-02 | Val Rel-L2: 2.122360e-01
# [deeponet_n50] Epoch  544/1000 | Train MSE(n): 1.011228e-02 | Val Rel-L2: 2.113507e-01
# ...
# [fedonet_n800] Epoch  829/1000 | Train MSE(n): 1.390125e-03 | Val Rel-L2: 5.537497e-02
# [fedonet_n800] Epoch  830/1000 | Train MSE(n): 1.387724e-03 | Val Rel-L2: 5.497698e-02
# [fedonet_n800] Epoch  831/1000 | Train MSE(n): 1.394123e-03 | Val Rel-L2: 5.529012e-02
# [fedonet_n800] Epoch  832/1000 | Train MSE(n): 1.386056e-03 | Val Rel-L2: 5.523701e-02
# [fedonet_n800] Epoch  833/1000 | Train MSE(n): 1.383510e-03 | Val Rel-L2: 5.522588e-02
# [fedonet_n800] Epoch  834/1000 | Train MSE(n): 1.387383e-03 | Val Rel-L2: 5.521613e-02
# [fedonet_n800] Epoch  835/1000 | Train MSE(n): 1.390345e-03 | Val Rel-L2: 5.517842e-02
# [fedonet_n800] Epoch  836/1000 | Train MSE(n): 1.389621e-03 | Val Rel-L2: 5.536247e-02
# [fedonet_n800] Epoch  837/1000 | Train MSE(n): 1.390957e-03 | Val Rel-L2: 5.571885e-02
# [fedonet_n800] Epoch  838/1000 | Train MSE(n): 1.389405e-03 | Val Rel-L2: 5.530389e-02
# [fedonet_n800] Epoch  839/1000 | Train MSE(n): 1.394146e-03 | Val Rel-L2: 5.527965e-02
# [fedonet_n800] Epoch  840/1000 | Train MSE(n): 1.399944e-03 | Val Rel-L2: 5.548825e-02
# [fedonet_n800] Epoch  841/1000 | Train MSE(n): 1.389838e-03 | Val Rel-L2: 5.492077e-02
# [fedonet_n800] Epoch  842/1000 | Train MSE(n): 1.391163e-03 | Val Rel-L2: 5.515659e-02
# [fedonet_n800] Epoch  843/1000 | Train MSE(n): 1.393222e-03 | Val Rel-L2: 5.515355e-02
# [fedonet_n800] Epoch  844/1000 | Train MSE(n): 1.399290e-03 | Val Rel-L2: 5.523821e-02
# [fedonet_n800] Epoch  845/1000 | Train MSE(n): 1.394047e-03 | Val Rel-L2: 5.527961e-02
# [fedonet_n800] Epoch  846/1000 | Train MSE(n): 1.389590e-03 | Val Rel-L2: 5.500348e-02
# [fedonet_n800] Epoch  847/1000 | Train MSE(n): 1.380383e-03 | Val Rel-L2: 5.504910e-02
# [fedonet_n800] Epoch  848/1000 | Train MSE(n): 1.378981e-03 | Val Rel-L2: 5.523329e-02
# [fedonet_n800] Epoch  849/1000 | Train MSE(n): 1.388123e-03 | Val Rel-L2: 5.539502e-02
# [fedonet_n800] Epoch  850/1000 | Train MSE(n): 1.389608e-03 | Val Rel-L2: 5.539657e-02
# [fedonet_n800] Epoch  851/1000 | Train MSE(n): 1.391256e-03 | Val Rel-L2: 5.490002e-02
# [fedonet_n800] Epoch  852/1000 | Train MSE(n): 1.389430e-03 | Val Rel-L2: 5.505902e-02
# [fedonet_n800] Epoch  853/1000 | Train MSE(n): 1.384433e-03 | Val Rel-L2: 5.532717e-02
# [fedonet_n800] Epoch  854/1000 | Train MSE(n): 1.378842e-03 | Val Rel-L2: 5.527384e-02
# [fedonet_n800] Epoch  855/1000 | Train MSE(n): 1.388210e-03 | Val Rel-L2: 5.512177e-02
# [fedonet_n800] Epoch  856/1000 | Train MSE(n): 1.387662e-03 | Val Rel-L2: 5.505068e-02
# [fedonet_n800] Epoch  857/1000 | Train MSE(n): 1.382650e-03 | Val Rel-L2: 5.519334e-02
# [fedonet_n800] Epoch  858/1000 | Train MSE(n): 1.382441e-03 | Val Rel-L2: 5.513366e-02
# [fedonet_n800] Epoch  859/1000 | Train MSE(n): 1.374511e-03 | Val Rel-L2: 5.510493e-02
# [fedonet_n800] Epoch  860/1000 | Train MSE(n): 1.374726e-03 | Val Rel-L2: 5.486667e-02
# [fedonet_n800] Epoch  861/1000 | Train MSE(n): 1.373227e-03 | Val Rel-L2: 5.536217e-02
# [fedonet_n800] Epoch  862/1000 | Train MSE(n): 1.374839e-03 | Val Rel-L2: 5.508497e-02
# [fedonet_n800] Epoch  863/1000 | Train MSE(n): 1.376835e-03 | Val Rel-L2: 5.520739e-02
# [fedonet_n800] Epoch  864/1000 | Train MSE(n): 1.374356e-03 | Val Rel-L2: 5.547920e-02
# [fedonet_n800] Epoch  865/1000 | Train MSE(n): 1.372754e-03 | Val Rel-L2: 5.516607e-02
# [fedonet_n800] Epoch  866/1000 | Train MSE(n): 1.368125e-03 | Val Rel-L2: 5.526405e-02
# [fedonet_n800] Epoch  867/1000 | Train MSE(n): 1.372967e-03 | Val Rel-L2: 5.529862e-02
# [fedonet_n800] Epoch  868/1000 | Train MSE(n): 1.368821e-03 | Val Rel-L2: 5.561655e-02
# [fedonet_n800] Epoch  869/1000 | Train MSE(n): 1.368366e-03 | Val Rel-L2: 5.521768e-02
# [fedonet_n800] Epoch  870/1000 | Train MSE(n): 1.371907e-03 | Val Rel-L2: 5.535371e-02
# [fedonet_n800] Epoch  871/1000 | Train MSE(n): 1.375717e-03 | Val Rel-L2: 5.525198e-02
# [fedonet_n800] Epoch  872/1000 | Train MSE(n): 1.374972e-03 | Val Rel-L2: 5.513520e-02
# [fedonet_n800] Epoch  873/1000 | Train MSE(n): 1.371386e-03 | Val Rel-L2: 5.492600e-02
# [fedonet_n800] Epoch  874/1000 | Train MSE(n): 1.366767e-03 | Val Rel-L2: 5.521881e-02
# [fedonet_n800] Epoch  875/1000 | Train MSE(n): 1.372636e-03 | Val Rel-L2: 5.527981e-02
# [fedonet_n800] Epoch  876/1000 | Train MSE(n): 1.372544e-03 | Val Rel-L2: 5.517702e-02
# [fedonet_n800] Epoch  877/1000 | Train MSE(n): 1.363582e-03 | Val Rel-L2: 5.530227e-02
# [fedonet_n800] Epoch  878/1000 | Train MSE(n): 1.364427e-03 | Val Rel-L2: 5.517720e-02
# [fedonet_n800] Epoch  879/1000 | Train MSE(n): 1.362777e-03 | Val Rel-L2: 5.510941e-02
# [fedonet_n800] Epoch  880/1000 | Train MSE(n): 1.365363e-03 | Val Rel-L2: 5.519680e-02
# [fedonet_n800] Epoch  881/1000 | Train MSE(n): 1.368355e-03 | Val Rel-L2: 5.520343e-02
# [fedonet_n800] Epoch  882/1000 | Train MSE(n): 1.369272e-03 | Val Rel-L2: 5.493770e-02
# [fedonet_n800] Epoch  883/1000 | Train MSE(n): 1.369591e-03 | Val Rel-L2: 5.474405e-02
# [fedonet_n800] Epoch  884/1000 | Train MSE(n): 1.366346e-03 | Val Rel-L2: 5.454198e-02
# [fedonet_n800] Epoch  885/1000 | Train MSE(n): 1.360151e-03 | Val Rel-L2: 5.458443e-02
# [fedonet_n800] Epoch  886/1000 | Train MSE(n): 1.361753e-03 | Val Rel-L2: 5.473916e-02
# [fedonet_n800] Epoch  887/1000 | Train MSE(n): 1.367023e-03 | Val Rel-L2: 5.468953e-02
# [fedonet_n800] Epoch  888/1000 | Train MSE(n): 1.369665e-03 | Val Rel-L2: 5.536105e-02
# [fedonet_n800] Epoch  889/1000 | Train MSE(n): 1.369908e-03 | Val Rel-L2: 5.505738e-02
# [fedonet_n800] Epoch  890/1000 | Train MSE(n): 1.366866e-03 | Val Rel-L2: 5.523274e-02
# [fedonet_n800] Epoch  891/1000 | Train MSE(n): 1.359402e-03 | Val Rel-L2: 5.504022e-02
# [fedonet_n800] Epoch  892/1000 | Train MSE(n): 1.361262e-03 | Val Rel-L2: 5.539229e-02
# [fedonet_n800] Epoch  893/1000 | Train MSE(n): 1.363483e-03 | Val Rel-L2: 5.521151e-02
# [fedonet_n800] Epoch  894/1000 | Train MSE(n): 1.360752e-03 | Val Rel-L2: 5.508210e-02
# [fedonet_n800] Epoch  895/1000 | Train MSE(n): 1.358243e-03 | Val Rel-L2: 5.516312e-02
# [fedonet_n800] Epoch  896/1000 | Train MSE(n): 1.370050e-03 | Val Rel-L2: 5.573460e-02
# [fedonet_n800] Epoch  897/1000 | Train MSE(n): 1.369834e-03 | Val Rel-L2: 5.529214e-02
# [fedonet_n800] Epoch  898/1000 | Train MSE(n): 1.379272e-03 | Val Rel-L2: 5.502185e-02
# [fedonet_n800] Epoch  899/1000 | Train MSE(n): 1.371619e-03 | Val Rel-L2: 5.515306e-02
# [fedonet_n800] Epoch  900/1000 | Train MSE(n): 1.382014e-03 | Val Rel-L2: 5.501704e-02
# [fedonet_n800] Epoch  901/1000 | Train MSE(n): 1.379157e-03 | Val Rel-L2: 5.519069e-02
# [fedonet_n800] Epoch  902/1000 | Train MSE(n): 1.365022e-03 | Val Rel-L2: 5.495855e-02
# [fedonet_n800] Epoch  903/1000 | Train MSE(n): 1.362039e-03 | Val Rel-L2: 5.535032e-02
# [fedonet_n800] Epoch  904/1000 | Train MSE(n): 1.360928e-03 | Val Rel-L2: 5.520729e-02
# [fedonet_n800] Epoch  905/1000 | Train MSE(n): 1.359403e-03 | Val Rel-L2: 5.566589e-02
# [fedonet_n800] Epoch  906/1000 | Train MSE(n): 1.355399e-03 | Val Rel-L2: 5.485765e-02
# [fedonet_n800] Epoch  907/1000 | Train MSE(n): 1.353247e-03 | Val Rel-L2: 5.512604e-02
# [fedonet_n800] Epoch  908/1000 | Train MSE(n): 1.355778e-03 | Val Rel-L2: 5.521551e-02
# [fedonet_n800] Epoch  909/1000 | Train MSE(n): 1.355057e-03 | Val Rel-L2: 5.499186e-02
# [fedonet_n800] Epoch  910/1000 | Train MSE(n): 1.354080e-03 | Val Rel-L2: 5.490766e-02
# [fedonet_n800] Epoch  911/1000 | Train MSE(n): 1.355356e-03 | Val Rel-L2: 5.558830e-02
# [fedonet_n800] Epoch  912/1000 | Train MSE(n): 1.351820e-03 | Val Rel-L2: 5.504579e-02
# [fedonet_n800] Epoch  913/1000 | Train MSE(n): 1.347945e-03 | Val Rel-L2: 5.511223e-02
# [fedonet_n800] Epoch  914/1000 | Train MSE(n): 1.342439e-03 | Val Rel-L2: 5.495534e-02
# [fedonet_n800] Epoch  915/1000 | Train MSE(n): 1.349893e-03 | Val Rel-L2: 5.530073e-02
# [fedonet_n800] Epoch  916/1000 | Train MSE(n): 1.337095e-03 | Val Rel-L2: 5.486514e-02
# [fedonet_n800] Epoch  917/1000 | Train MSE(n): 1.330088e-03 | Val Rel-L2: 5.465693e-02
# [fedonet_n800] Epoch  918/1000 | Train MSE(n): 1.328920e-03 | Val Rel-L2: 5.486041e-02
# [fedonet_n800] Epoch  919/1000 | Train MSE(n): 1.329349e-03 | Val Rel-L2: 5.472445e-02
# [fedonet_n800] Epoch  920/1000 | Train MSE(n): 1.330717e-03 | Val Rel-L2: 5.484209e-02
# [fedonet_n800] Epoch  921/1000 | Train MSE(n): 1.328143e-03 | Val Rel-L2: 5.489621e-02
# [fedonet_n800] Epoch  922/1000 | Train MSE(n): 1.329266e-03 | Val Rel-L2: 5.462426e-02
# [fedonet_n800] Epoch  923/1000 | Train MSE(n): 1.329238e-03 | Val Rel-L2: 5.482079e-02
# [fedonet_n800] Epoch  924/1000 | Train MSE(n): 1.329658e-03 | Val Rel-L2: 5.474546e-02
# [fedonet_n800] Epoch  925/1000 | Train MSE(n): 1.323713e-03 | Val Rel-L2: 5.470109e-02
# [fedonet_n800] Epoch  926/1000 | Train MSE(n): 1.326396e-03 | Val Rel-L2: 5.492605e-02
# [fedonet_n800] Epoch  927/1000 | Train MSE(n): 1.326386e-03 | Val Rel-L2: 5.477554e-02
# [fedonet_n800] Epoch  928/1000 | Train MSE(n): 1.326240e-03 | Val Rel-L2: 5.491142e-02
# [fedonet_n800] Epoch  929/1000 | Train MSE(n): 1.324841e-03 | Val Rel-L2: 5.489158e-02
# [fedonet_n800] Epoch  930/1000 | Train MSE(n): 1.327263e-03 | Val Rel-L2: 5.512419e-02
# [fedonet_n800] Epoch  931/1000 | Train MSE(n): 1.324884e-03 | Val Rel-L2: 5.477316e-02
# [fedonet_n800] Epoch  932/1000 | Train MSE(n): 1.323495e-03 | Val Rel-L2: 5.496470e-02
# [fedonet_n800] Epoch  933/1000 | Train MSE(n): 1.323768e-03 | Val Rel-L2: 5.493262e-02
# [fedonet_n800] Epoch  934/1000 | Train MSE(n): 1.326058e-03 | Val Rel-L2: 5.485789e-02
# [fedonet_n800] Epoch  935/1000 | Train MSE(n): 1.322273e-03 | Val Rel-L2: 5.476978e-02
# [fedonet_n800] Epoch  936/1000 | Train MSE(n): 1.323266e-03 | Val Rel-L2: 5.453511e-02
# [fedonet_n800] Epoch  937/1000 | Train MSE(n): 1.324167e-03 | Val Rel-L2: 5.460339e-02
# [fedonet_n800] Epoch  938/1000 | Train MSE(n): 1.324780e-03 | Val Rel-L2: 5.471968e-02
# [fedonet_n800] Epoch  939/1000 | Train MSE(n): 1.326956e-03 | Val Rel-L2: 5.464589e-02
# [fedonet_n800] Epoch  940/1000 | Train MSE(n): 1.323111e-03 | Val Rel-L2: 5.473246e-02
# [fedonet_n800] Epoch  941/1000 | Train MSE(n): 1.324012e-03 | Val Rel-L2: 5.485699e-02
# [fedonet_n800] Epoch  942/1000 | Train MSE(n): 1.326210e-03 | Val Rel-L2: 5.453371e-02
# [fedonet_n800] Epoch  943/1000 | Train MSE(n): 1.325371e-03 | Val Rel-L2: 5.460302e-02
# [fedonet_n800] Epoch  944/1000 | Train MSE(n): 1.321700e-03 | Val Rel-L2: 5.447334e-02
# [fedonet_n800] Epoch  945/1000 | Train MSE(n): 1.321063e-03 | Val Rel-L2: 5.435972e-02
# [fedonet_n800] Epoch  946/1000 | Train MSE(n): 1.318442e-03 | Val Rel-L2: 5.454101e-02
# [fedonet_n800] Epoch  947/1000 | Train MSE(n): 1.321753e-03 | Val Rel-L2: 5.479607e-02
# [fedonet_n800] Epoch  948/1000 | Train MSE(n): 1.323588e-03 | Val Rel-L2: 5.472243e-02
# [fedonet_n800] Epoch  949/1000 | Train MSE(n): 1.327785e-03 | Val Rel-L2: 5.485635e-02
# [fedonet_n800] Epoch  950/1000 | Train MSE(n): 1.325929e-03 | Val Rel-L2: 5.459025e-02
# [fedonet_n800] Epoch  951/1000 | Train MSE(n): 1.326560e-03 | Val Rel-L2: 5.455080e-02
# [fedonet_n800] Epoch  952/1000 | Train MSE(n): 1.324648e-03 | Val Rel-L2: 5.479157e-02
# [fedonet_n800] Epoch  953/1000 | Train MSE(n): 1.322237e-03 | Val Rel-L2: 5.455977e-02
# [fedonet_n800] Epoch  954/1000 | Train MSE(n): 1.319924e-03 | Val Rel-L2: 5.466900e-02
# [fedonet_n800] Epoch  955/1000 | Train MSE(n): 1.320004e-03 | Val Rel-L2: 5.465435e-02
# [fedonet_n800] Epoch  956/1000 | Train MSE(n): 1.317724e-03 | Val Rel-L2: 5.434208e-02
# [fedonet_n800] Epoch  957/1000 | Train MSE(n): 1.321103e-03 | Val Rel-L2: 5.446901e-02
# [fedonet_n800] Epoch  958/1000 | Train MSE(n): 1.317207e-03 | Val Rel-L2: 5.455791e-02
# [fedonet_n800] Epoch  959/1000 | Train MSE(n): 1.317645e-03 | Val Rel-L2: 5.451549e-02
# [fedonet_n800] Epoch  960/1000 | Train MSE(n): 1.317026e-03 | Val Rel-L2: 5.464369e-02
# [fedonet_n800] Epoch  961/1000 | Train MSE(n): 1.317856e-03 | Val Rel-L2: 5.461959e-02
# [fedonet_n800] Epoch  962/1000 | Train MSE(n): 1.315334e-03 | Val Rel-L2: 5.456749e-02
# [fedonet_n800] Epoch  963/1000 | Train MSE(n): 1.318064e-03 | Val Rel-L2: 5.470235e-02
# [fedonet_n800] Epoch  964/1000 | Train MSE(n): 1.318601e-03 | Val Rel-L2: 5.436497e-02
# [fedonet_n800] Epoch  965/1000 | Train MSE(n): 1.318018e-03 | Val Rel-L2: 5.432754e-02
# [fedonet_n800] Epoch  966/1000 | Train MSE(n): 1.315747e-03 | Val Rel-L2: 5.444763e-02
# [fedonet_n800] Epoch  967/1000 | Train MSE(n): 1.312329e-03 | Val Rel-L2: 5.444777e-02
# [fedonet_n800] Epoch  968/1000 | Train MSE(n): 1.317008e-03 | Val Rel-L2: 5.472519e-02
# [fedonet_n800] Epoch  969/1000 | Train MSE(n): 1.316594e-03 | Val Rel-L2: 5.454040e-02
# [fedonet_n800] Epoch  970/1000 | Train MSE(n): 1.314924e-03 | Val Rel-L2: 5.455083e-02
# [fedonet_n800] Epoch  971/1000 | Train MSE(n): 1.317909e-03 | Val Rel-L2: 5.468138e-02
# [fedonet_n800] Epoch  972/1000 | Train MSE(n): 1.314604e-03 | Val Rel-L2: 5.457534e-02
# [fedonet_n800] Epoch  973/1000 | Train MSE(n): 1.313744e-03 | Val Rel-L2: 5.463415e-02
# [fedonet_n800] Epoch  974/1000 | Train MSE(n): 1.314369e-03 | Val Rel-L2: 5.459565e-02
# [fedonet_n800] Epoch  975/1000 | Train MSE(n): 1.316059e-03 | Val Rel-L2: 5.427502e-02
# [fedonet_n800] Epoch  976/1000 | Train MSE(n): 1.313017e-03 | Val Rel-L2: 5.445078e-02
# [fedonet_n800] Epoch  977/1000 | Train MSE(n): 1.311736e-03 | Val Rel-L2: 5.424751e-02
# [fedonet_n800] Epoch  978/1000 | Train MSE(n): 1.312906e-03 | Val Rel-L2: 5.453375e-02
# [fedonet_n800] Epoch  979/1000 | Train MSE(n): 1.311582e-03 | Val Rel-L2: 5.439943e-02
# [fedonet_n800] Epoch  980/1000 | Train MSE(n): 1.313085e-03 | Val Rel-L2: 5.453332e-02
# [fedonet_n800] Epoch  981/1000 | Train MSE(n): 1.314602e-03 | Val Rel-L2: 5.454525e-02
# [fedonet_n800] Epoch  982/1000 | Train MSE(n): 1.313915e-03 | Val Rel-L2: 5.451369e-02
# [fedonet_n800] Epoch  983/1000 | Train MSE(n): 1.309593e-03 | Val Rel-L2: 5.413098e-02
# [fedonet_n800] Epoch  984/1000 | Train MSE(n): 1.311417e-03 | Val Rel-L2: 5.444524e-02
# [fedonet_n800] Epoch  985/1000 | Train MSE(n): 1.319517e-03 | Val Rel-L2: 5.444447e-02
# [fedonet_n800] Epoch  986/1000 | Train MSE(n): 1.317923e-03 | Val Rel-L2: 5.459700e-02
# [fedonet_n800] Epoch  987/1000 | Train MSE(n): 1.314591e-03 | Val Rel-L2: 5.485318e-02
# [fedonet_n800] Epoch  988/1000 | Train MSE(n): 1.312500e-03 | Val Rel-L2: 5.458929e-02
# [fedonet_n800] Epoch  989/1000 | Train MSE(n): 1.314478e-03 | Val Rel-L2: 5.423476e-02
# [fedonet_n800] Epoch  990/1000 | Train MSE(n): 1.314940e-03 | Val Rel-L2: 5.419706e-02
# [fedonet_n800] Epoch  991/1000 | Train MSE(n): 1.310249e-03 | Val Rel-L2: 5.459371e-02
# [fedonet_n800] Epoch  992/1000 | Train MSE(n): 1.304754e-03 | Val Rel-L2: 5.464476e-02
# [fedonet_n800] Epoch  993/1000 | Train MSE(n): 1.303421e-03 | Val Rel-L2: 5.429948e-02
# [fedonet_n800] Epoch  994/1000 | Train MSE(n): 1.306900e-03 | Val Rel-L2: 5.427604e-02
# [fedonet_n800] Epoch  995/1000 | Train MSE(n): 1.304675e-03 | Val Rel-L2: 5.459195e-02
# [fedonet_n800] Epoch  996/1000 | Train MSE(n): 1.308053e-03 | Val Rel-L2: 5.458655e-02
# [fedonet_n800] Epoch  997/1000 | Train MSE(n): 1.305612e-03 | Val Rel-L2: 5.441196e-02
# [fedonet_n800] Epoch  998/1000 | Train MSE(n): 1.306535e-03 | Val Rel-L2: 5.416005e-02
# [fedonet_n800] Epoch  999/1000 | Train MSE(n): 1.304572e-03 | Val Rel-L2: 5.441573e-02
# [fedonet_n800] Epoch 1000/1000 | Train MSE(n): 1.306038e-03 | Val Rel-L2: 5.423529e-02
# [FEDONet  | n=800] Best Val Rel-L2 : 5.413098e-02
# [FEDONet  | n=800] Test Mean Rel-L2: 4.800650e-02
#
# ==============================================================================================================
# FINAL SUMMARY: Training Data Size vs Rel-L2 Error
# ==============================================================================================================
# n_train=  50 | DeepONet  Val=2.071393e-01, Test=1.870480e-01 | FEDONet  Val=1.811015e-01, Test=1.462360e-01
# n_train= 100 | DeepONet  Val=1.549845e-01, Test=1.410117e-01 | FEDONet  Val=1.294325e-01, Test=1.042205e-01
# n_train= 300 | DeepONet  Val=9.780489e-02, Test=8.641844e-02 | FEDONet  Val=8.420211e-02, Test=6.883478e-02
# n_train= 400 | DeepONet  Val=9.315946e-02, Test=7.440453e-02 | FEDONet  Val=8.810093e-02, Test=6.879737e-02
# n_train= 500 | DeepONet  Val=8.257571e-02, Test=6.646415e-02 | FEDONet  Val=7.078826e-02, Test=5.605671e-02
# n_train= 800 | DeepONet  Val=6.358711e-02, Test=5.521173e-02 | FEDONet  Val=5.413098e-02, Test=4.800650e-02

# %%
import matplotlib as mpl


def set_plot_params():
    mpl.rcParams['figure.figsize'] = (8, 6)
    mpl.rcParams['figure.dpi'] = 100
    mpl.rcParams['savefig.dpi'] = 300
    mpl.rcParams['font.family'] = 'serif'
    mpl.rcParams['font.size'] = 15
    mpl.rcParams['axes.titlesize'] = 16
    mpl.rcParams['axes.labelsize'] = 14
    mpl.rcParams['xtick.labelsize'] = 12
    mpl.rcParams['ytick.labelsize'] = 12
    mpl.rcParams['legend.fontsize'] = 12
    mpl.rcParams['grid.linestyle'] = '--'
    mpl.rcParams['grid.color'] = 'gray'
    mpl.rcParams['grid.alpha'] = 0.5
    mpl.rcParams['image.cmap'] = 'viridis'

set_plot_params()

plt.rcParams.update({
    'font.size': 16,
    'axes.titlesize': 21,
    'axes.labelsize': 18,
    'xtick.labelsize': 15,
    'ytick.labelsize': 15,
    'legend.fontsize': 16
})

train_percent = 100.0 * train_sizes_arr / n_train_full

plt.figure(figsize=(8, 5))
plt.plot(train_sizes_arr, fed_test_arr, marker='s', linewidth=2, label='FEDONet')
plt.plot(train_sizes_arr, deep_test_arr, marker='o', linewidth=2, label='DeepONet')

# plt.yscale('log')
plt.xlabel('Number of Training Samples')
plt.ylabel('Mean Relative $L^2$ Error')
# plt.title('Test Rel-L2 vs Fraction of Training Data', fontsize=14)
plt.grid(True, which='both', linestyle='--', alpha=0.4)
plt.legend()
plt.tight_layout()
plt.show()
